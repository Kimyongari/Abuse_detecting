# %%
import os
from glob import glob
import warnings
import random
warnings.filterwarnings('ignore')

import import_ipynb
import abuse_detecting_preprocessing as pp
import abuse_detecting_databuild as b

import pandas as pd
import numpy as np

import fasttext

import tensorflow as tf
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, Dropout, BatchNormalization, GRU
from tensorflow.keras.layers import LeakyReLU, Input, Bidirectional, LSTM, GlobalMaxPooling1D, concatenate, ReLU
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import callbacks
from scikeras.wrappers import KerasClassifier

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, precision_recall_curve, roc_curve
from sklearn.model_selection import GridSearchCV

import matplotlib.pyplot as plt
import seaborn as sns

# %%
def seed_everything(seed=0):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
SEED = 30
seed_everything(SEED)

# %%
def print_score(label, pred):
    print('Precision: {:.5f}'.format(precision_score(label, pred)))
    print('Recall: {:.5f}'.format(recall_score(label, pred)))
    print('F1 Score: {:.5f}'.format(f1_score(label, pred)))
    print('Accuracy : {:.5f}'.format(np.mean(label == pred)))
    print('ROC AUC Score: {:.5f}\n'.format(roc_auc_score(label, pred)))

# %%
def _1DCNN(dropout_rate, input_shape):
    
    model = Sequential()
    model.add(Conv1D(filters=64, kernel_size = 6, input_shape = input_shape))
    model.add(LeakyReLU(alpha=0.2))
    # input_shape = (25, 100)
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(dropout_rate))
    
    model.add(Conv1D(filters=128, kernel_size = 3))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(dropout_rate))
    
    model.add(Conv1D(filters=256, kernel_size = 1))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization())
    model.add(GlobalAveragePooling1D())
    model.add(Dropout(dropout_rate))  
    
    model.add(Dense(128))
    model.add(ReLU())
    model.add(Dense(1, activation ='sigmoid'))
    
    model.compile(loss = 'binary_crossentropy',
                  optimizer = 'Adam',
                  metrics = ['accuracy'])
    
    return model

# %%
def combined_pooling_lstm_model(dropout_rate, input_shape):
    
    inputs = Input(shape = input_shape)
    
    # Bidirectional LSTM layer
    x = Bidirectional(LSTM(64, return_sequences = True))(inputs)
    x = Bidirectional(LSTM(64, return_sequences = True))(x)
    
    # Average pool과 Max pool 생성
    avg_pool = GlobalAveragePooling1D()(x)
    max_pool = GlobalMaxPooling1D()(x)
    
    # 두 pool을 합친다.
    combined_pool = concatenate([avg_pool, max_pool])
    combined_pool = BatchNormalization()(combined_pool)
    
    # Dropout
    combined_pool = Dropout(dropout_rate)(combined_pool)
    
    # Output
    outputs = Dense(128)(combined_pool)
    outputs = ReLU()(outputs)
    
    outputs = Dense(1, activation='sigmoid')(outputs)
    
    model = Model(inputs = inputs, outputs = outputs)
    model.compile(loss = "binary_crossentropy",
                  optimizer = 'Adam',
                  metrics = ['accuracy'])
        
    return model

# %%
def GRU_model(dropout_rate, input_shape):
    
    model = Sequential()

    model.add(GRU(128, return_sequences = True, input_shape = input_shape))
    model.add(LeakyReLU(alpha = 0.2))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    model.add(GRU(64, return_sequences = True))
    model.add(LeakyReLU(alpha = 0.2))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    model.add(GRU(32, return_sequences = False))
    model.add(LeakyReLU(alpha = 0.2))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    # output
    model.add(Dense(32))
    model.add(ReLU())
    model.add(Dense(1, activation = 'sigmoid'))
    
    # Model compile
    model.compile(loss = 'binary_crossentropy',
                  optimizer ='Adam',
                  metrics = ['accuracy'])
    
    return model

# %%
def build_train(routes, input_,):
    fasttext_model = fasttext.load_model('fasttext_model.bin')
    
    df = pd.DataFrame()
    for r in routes:
        d = pd.read_csv(r)
        df = pd.concat([df,d], ignore_index = True)

    N = 5
    # df = df[['문장','악플/욕설']]
    # df = df.rename(columns = {'문장' : 'message', '악플/욕설' : 'label'})
    x_train = b.making_x_train(df['message'], input_, fasttext_model, N)
    y_train = np.array(df['label'])
    
    y_train = y_train.astype(np.float32)
    y_train = y_train.reshape(-1,1)
    
    x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, stratify = y_train, random_state = SEED,
                                                       train_size = 0.8, test_size = 0.2)
    print('x_train :', x_train.shape, 'y_train :', y_train.shape)
    print('x_test :', x_test.shape, 'y_test :', y_test.shape)

    return x_train, y_train, x_test, y_test

# %%
def train(model, train_set, k, epochs):
    x_train, y_train = train_set
    # train
    kf = KFold(n_splits = k, shuffle=True)

    for idx, (train_index, val_index) in enumerate(kf.split(x_train)):
        print(f'\n--{idx + 1}/{k} fold--\n')
        
        x_train_fold, x_val_fold = x_train[train_index], x_train[val_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]
        
        model.fit(x_train_fold, y_train_fold, epochs = epochs,
                  validation_data = (x_val_fold, y_val_fold), callbacks = [early_stopping])
        
    print(f'\n--{model}--\n')
    y_pred = np.round(model.predict(x_test))
    print_score(y_pred, y_test)
    
    return model

# %%
def my_GridSearch(model, train_set, param_grid, cv, input_shape, verbose = 0, n_jobs = 5):
    train, y = train_set

    classifier = KerasClassifier(build_fn = model, input_shape = input_shape, dropout_rate = 0.0)
    # GridSearchCV 모델로 초기화
    grid_model = GridSearchCV(estimator = classifier,
                           param_grid = param_grid,
                           scoring = 'roc_auc',
                           cv = cv)
    
    # 모델 fitting
    grid_model.fit(train, y)
    
    # 최적의 하이퍼파라미터 및 점수 출력
    print("Best parameters found: ", grid_model.best_params_)
    print("Best ROC AUC score: ", grid_model.best_score_)
    
    # 결과값 저장
    results = pd.DataFrame(grid_model.cv_results_)
    results = results.sort_values(by='mean_test_score', ascending=False)
    
    return results

# %%
def ensemble(models, test_set):
    x_test, y_test = test_set
    pred = np.column_stack([m.predict(x_test) for m in models])
    ensembled_pred = np.round(np.mean(pred, axis = 1))

    for p in pred.transpose():
        print_score(y_test, np.round(p))
    print('--ensembeld_model--')
    print_score(y_test, ensembled_pred)

# %%
K = 5
_input = 40 # 단어 길이
input_shape = (_input, 100) # fasttext 모델이 100개의 벡터로 반환함.
dropout_rate = 0.0
early_stopping = EarlyStopping(monitor = 'val_loss', patience = 5) 

data_routes = glob('/Users/kim-yongjun/Documents/chatting_data/LCK_spring_chat/labeled_data/*.csv')[:5]
# data_routes = glob('/Users/kim-yongjun/Documents/chatting_data/smile_gate_abuse_data/*')
x_train, y_train, x_test, y_test = build_train(data_routes, _input)
train_set = (x_train, y_train)
test_set = (x_test, y_test)
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# x_train : (2711, 40, 100) y_train : (2711, 1)
# x_test : (678, 40, 100) y_test : (678, 1)

# %%
cv = 5 # grid_search의 cv

param_grid = {'epochs': [6, 8, 10],
              'dropout_rate': [0.2, 0.3, 0.4]
             }
# 총 90 + 120 + 150 = 360회 수행.

# %%
_1DCNN_grid = my_GridSearch(_1DCNN, train_set, param_grid, cv, input_shape)

# %%
_1DCNN_grid[['rank_test_score', 'params', 'mean_test_score']]
# Out:
#    rank_test_score                               params  mean_test_score
# 5                1  {'dropout_rate': 0.3, 'epochs': 10}         0.799668
# 8                2  {'dropout_rate': 0.4, 'epochs': 10}         0.797515
# 4                3   {'dropout_rate': 0.3, 'epochs': 8}         0.796372
# 7                4   {'dropout_rate': 0.4, 'epochs': 8}         0.793104
# 6                5   {'dropout_rate': 0.4, 'epochs': 6}         0.784711
# 3                6   {'dropout_rate': 0.3, 'epochs': 6}         0.775195
# 2                7  {'dropout_rate': 0.2, 'epochs': 10}         0.768342
# 0                8   {'dropout_rate': 0.2, 'epochs': 6}         0.764591
# 1                9   {'dropout_rate': 0.2, 'epochs': 8}         0.754953

# %%
GRU_grid = my_GridSearch(GRU_model, train_set, param_grid, cv, input_shape)

# %%
GRU_grid[['rank_test_score', 'params', 'mean_test_score']]
# Out:
#    rank_test_score                               params  mean_test_score
# 5                1  {'dropout_rate': 0.3, 'epochs': 10}         0.694816
# 4                2   {'dropout_rate': 0.3, 'epochs': 8}         0.691399
# 2                3  {'dropout_rate': 0.2, 'epochs': 10}         0.657852
# 6                4   {'dropout_rate': 0.4, 'epochs': 6}         0.657315
# 7                5   {'dropout_rate': 0.4, 'epochs': 8}         0.653513
# 3                6   {'dropout_rate': 0.3, 'epochs': 6}         0.645841
# 1                7   {'dropout_rate': 0.2, 'epochs': 8}         0.600583
# 0                8   {'dropout_rate': 0.2, 'epochs': 6}         0.596483
# 8                9  {'dropout_rate': 0.4, 'epochs': 10}         0.568222

# %%
lstm_grid = my_GridSearch(combined_pooling_lstm_model, train_set, param_grid, cv, input_shape)

# %%
# lstm_grid[['rank_test_score', 'params']]
lstm_grid[['rank_test_score', 'params', 'mean_test_score']].reset_index(drop = True)
# Out:
#    rank_test_score                               params  mean_test_score
# 0                1   {'dropout_rate': 0.4, 'epochs': 8}         0.828229
# 1                2  {'dropout_rate': 0.3, 'epochs': 10}         0.813455
# 2                3   {'dropout_rate': 0.4, 'epochs': 6}         0.802773
# 3                4   {'dropout_rate': 0.2, 'epochs': 8}         0.799130
# 4                5   {'dropout_rate': 0.3, 'epochs': 6}         0.792878
# 5                6   {'dropout_rate': 0.2, 'epochs': 6}         0.792361
# 6                7  {'dropout_rate': 0.2, 'epochs': 10}         0.789558
# 7                8  {'dropout_rate': 0.4, 'epochs': 10}         0.773894
# 8                9   {'dropout_rate': 0.3, 'epochs': 8}         0.771561

# %%
_1DCNN_best = _1DCNN_grid[lstm_grid['rank_test_score'] == 1]['params'].item()
GRU_best = GRU_grid[lstm_grid['rank_test_score'] == 1]['params'].item()
BiLSTM_best = lstm_grid[lstm_grid['rank_test_score'] == 1]['params'].item()

_1DCNN_model = _1DCNN(_1DCNN_best['dropout_rate'], input_shape)
_GRU_model =  GRU_model(GRU_best['dropout_rate'], input_shape)
_BiLSTM_model = combined_pooling_lstm_model(BiLSTM_best['dropout_rate'], input_shape)

# %%
_1DCNN_model = train(_1DCNN_model, train_set, K, _1DCNN_best['epochs'])
_GRU_model = train(_GRU_model, train_set, K, GRU_best['epochs'])
_BiLSTM_model = train(_BiLSTM_model, train_set, K, BiLSTM_best['epochs'])
# Out:
# --1/5 fold--
#
# Epoch 1/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8022 - loss: 0.4720 - val_accuracy: 0.8821 - val_loss: 0.3221
# Epoch 2/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8997 - loss: 0.2838 - val_accuracy: 0.8987 - val_loss: 0.3404
# Epoch 3/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9098 - loss: 0.2525 - val_accuracy: 0.9024 - val_loss: 0.4312
# Epoch 4/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9198 - loss: 0.2154 - val_accuracy: 0.9024 - val_loss: 0.4671
# Epoch 5/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9305 - loss: 0.1937 - val_accuracy: 0.9024 - val_loss: 0.4525
# Epoch 6/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9403 - loss: 0.1774 - val_accuracy: 0.9079 - val_loss: 0.4154
#
# --2/5 fold--
#
# Epoch 1/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9283 - loss: 0.1929 - val_accuracy: 0.8911 - val_loss: 0.3592
# Epoch 2/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9327 - loss: 0.1775 - val_accuracy: 0.9022 - val_loss: 0.3153
# Epoch 3/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9306 - loss: 0.1692 - val_accuracy: 0.8948 - val_loss: 0.4948
# Epoch 4/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9507 - loss: 0.1385 - val_accuracy: 0.8856 - val_loss: 0.6085
# Epoch 5/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9539 - loss: 0.1252 - val_accuracy: 0.8930 - val_loss: 0.6954
# Epoch 6/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9633 - loss: 0.1073 - val_accuracy: 0.8893 - val_loss: 0.7890
# Epoch 7/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9745 - loss: 0.0781 - val_accuracy: 0.9077 - val_loss: 0.5629
#
# --3/5 fold--
#
# Epoch 1/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9482 - loss: 0.1669 - val_accuracy: 0.9391 - val_loss: 0.1299
# Epoch 2/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9532 - loss: 0.1242 - val_accuracy: 0.9244 - val_loss: 0.1759
# Epoch 3/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9632 - loss: 0.0944 - val_accuracy: 0.9299 - val_loss: 0.2073
# Epoch 4/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9718 - loss: 0.0830 - val_accuracy: 0.9317 - val_loss: 0.2283
# Epoch 5/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9748 - loss: 0.0853 - val_accuracy: 0.9391 - val_loss: 0.1945
# Epoch 6/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9772 - loss: 0.0666 - val_accuracy: 0.9225 - val_loss: 0.2718
#
# --4/5 fold--
#
# Epoch 1/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9639 - loss: 0.1324 - val_accuracy: 0.9520 - val_loss: 0.1276
# Epoch 2/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9695 - loss: 0.0855 - val_accuracy: 0.9649 - val_loss: 0.1286
# Epoch 3/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9676 - loss: 0.0824 - val_accuracy: 0.9151 - val_loss: 0.3566
# Epoch 4/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9790 - loss: 0.0657 - val_accuracy: 0.9391 - val_loss: 0.2102
# Epoch 5/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9895 - loss: 0.0383 - val_accuracy: 0.9262 - val_loss: 0.3295
# Epoch 6/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9848 - loss: 0.0461 - val_accuracy: 0.9373 - val_loss: 0.2948
#
# --5/5 fold--
#
# Epoch 1/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9714 - loss: 0.0875 - val_accuracy: 0.9483 - val_loss: 0.1206
# Epoch 2/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9775 - loss: 0.0667 - val_accuracy: 0.9151 - val_loss: 0.2829
# Epoch 3/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9832 - loss: 0.0481 - val_accuracy: 0.9557 - val_loss: 0.1306
# Epoch 4/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9839 - loss: 0.0569 - val_accuracy: 0.9151 - val_loss: 0.3750
# Epoch 5/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9811 - loss: 0.0525 - val_accuracy: 0.9465 - val_loss: 0.1741
# Epoch 6/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9828 - loss: 0.0468 - val_accuracy: 0.9114 - val_loss: 0.4415
#
# --<Sequential name=sequential_103, built=True>--
#
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Precision: 1.00000
# Recall: 0.89545
# F1 Score: 0.94484
# Accuracy : 0.89823
# ROC AUC Score: 0.94773
#
#
# --1/5 fold--
#
# Epoch 1/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.5785 - loss: 0.7523 - val_accuracy: 0.8711 - val_loss: 0.5671
# Epoch 2/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.8501 - loss: 0.4100 - val_accuracy: 0.8711 - val_loss: 0.5040
# Epoch 3/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8627 - loss: 0.4059 - val_accuracy: 0.8711 - val_loss: 0.4128
# Epoch 4/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8636 - loss: 0.3920 - val_accuracy: 0.8711 - val_loss: 0.3676
# Epoch 5/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8682 - loss: 0.3712 - val_accuracy: 0.8711 - val_loss: 0.3621
#
# --2/5 fold--
#
# Epoch 1/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8708 - loss: 0.3723 - val_accuracy: 0.8930 - val_loss: 0.3186
# Epoch 2/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.8728 - loss: 0.3608 - val_accuracy: 0.8967 - val_loss: 0.3155
# Epoch 3/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8721 - loss: 0.3531 - val_accuracy: 0.8967 - val_loss: 0.3160
# Epoch 4/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8820 - loss: 0.3290 - val_accuracy: 0.9077 - val_loss: 0.2931
# Epoch 5/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8879 - loss: 0.3072 - val_accuracy: 0.8745 - val_loss: 0.3002
#
# --3/5 fold--
#
# Epoch 1/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9112 - loss: 0.2600 - val_accuracy: 0.9133 - val_loss: 0.2430
# Epoch 2/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9138 - loss: 0.2528 - val_accuracy: 0.9077 - val_loss: 0.3155
# Epoch 3/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9122 - loss: 0.2504 - val_accuracy: 0.9170 - val_loss: 0.2716
# Epoch 4/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9246 - loss: 0.2083 - val_accuracy: 0.9059 - val_loss: 0.2787
# Epoch 5/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9321 - loss: 0.1937 - val_accuracy: 0.8985 - val_loss: 0.3070
#
# --4/5 fold--
#
# Epoch 1/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9285 - loss: 0.2177 - val_accuracy: 0.9391 - val_loss: 0.1974
# Epoch 2/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9335 - loss: 0.1879 - val_accuracy: 0.9188 - val_loss: 0.2996
# Epoch 3/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9414 - loss: 0.1670 - val_accuracy: 0.9077 - val_loss: 0.3227
# Epoch 4/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9412 - loss: 0.1643 - val_accuracy: 0.9391 - val_loss: 0.2602
# Epoch 5/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9574 - loss: 0.1219 - val_accuracy: 0.9280 - val_loss: 0.2731
#
# --5/5 fold--
#
# Epoch 1/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9547 - loss: 0.1427 - val_accuracy: 0.9742 - val_loss: 0.0772
# Epoch 2/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9628 - loss: 0.1321 - val_accuracy: 0.9668 - val_loss: 0.0806
# Epoch 3/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9713 - loss: 0.0984 - val_accuracy: 0.9594 - val_loss: 0.0928
# Epoch 4/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9719 - loss: 0.0895 - val_accuracy: 0.9649 - val_loss: 0.1035
# Epoch 5/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9824 - loss: 0.0836 - val_accuracy: 0.9557 - val_loss: 0.1154
# Epoch 6/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9827 - loss: 0.0608 - val_accuracy: 0.9410 - val_loss: 0.1798
#
# --<Sequential name=sequential_104, built=True>--
#
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# Precision: 0.88663
# Recall: 0.95273
# F1 Score: 0.91849
# Accuracy : 0.86283
# ROC AUC Score: 0.71464
#
#
# --1/5 fold--
#
# Epoch 1/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.8480 - loss: 0.3824 - val_accuracy: 0.8656 - val_loss: 0.5143
# Epoch 2/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9201 - loss: 0.2466 - val_accuracy: 0.8748 - val_loss: 0.4248
# Epoch 3/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9199 - loss: 0.1925 - val_accuracy: 0.8877 - val_loss: 0.3569
# Epoch 4/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9377 - loss: 0.1540 - val_accuracy: 0.8987 - val_loss: 0.3119
# Epoch 5/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9603 - loss: 0.1038 - val_accuracy: 0.9024 - val_loss: 0.2997
#
# --2/5 fold--
#
# Epoch 1/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9377 - loss: 0.1885 - val_accuracy: 0.9391 - val_loss: 0.1350
# Epoch 2/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9579 - loss: 0.1328 - val_accuracy: 0.9373 - val_loss: 0.1349
# Epoch 3/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9608 - loss: 0.0969 - val_accuracy: 0.9317 - val_loss: 0.2109
# Epoch 4/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9631 - loss: 0.0944 - val_accuracy: 0.9280 - val_loss: 0.2009
# Epoch 5/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9826 - loss: 0.0479 - val_accuracy: 0.9244 - val_loss: 0.2773
#
# --3/5 fold--
#
# Epoch 1/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9743 - loss: 0.0727 - val_accuracy: 0.9705 - val_loss: 0.0808
# Epoch 2/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9808 - loss: 0.0650 - val_accuracy: 0.9742 - val_loss: 0.0634
# Epoch 3/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9814 - loss: 0.0459 - val_accuracy: 0.9779 - val_loss: 0.0714
# Epoch 4/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.9889 - loss: 0.0372 - val_accuracy: 0.9742 - val_loss: 0.0668
# Epoch 5/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9942 - loss: 0.0232 - val_accuracy: 0.9760 - val_loss: 0.0672
# Epoch 6/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9964 - loss: 0.0141 - val_accuracy: 0.9668 - val_loss: 0.0871
# Epoch 7/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.9925 - loss: 0.0206 - val_accuracy: 0.9613 - val_loss: 0.1056
#
# --4/5 fold--
#
# Epoch 1/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9840 - loss: 0.0442 - val_accuracy: 0.9834 - val_loss: 0.0518
# Epoch 2/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9832 - loss: 0.0421 - val_accuracy: 0.9815 - val_loss: 0.0485
# Epoch 3/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9905 - loss: 0.0302 - val_accuracy: 0.9815 - val_loss: 0.0801
# Epoch 4/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9932 - loss: 0.0267 - val_accuracy: 0.9834 - val_loss: 0.0386
# Epoch 5/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9931 - loss: 0.0196 - val_accuracy: 0.9908 - val_loss: 0.0355
# Epoch 6/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9966 - loss: 0.0175 - val_accuracy: 0.9871 - val_loss: 0.0558
# Epoch 7/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.9950 - loss: 0.0197 - val_accuracy: 0.9889 - val_loss: 0.0358
# Epoch 8/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9925 - loss: 0.0180 - val_accuracy: 0.9852 - val_loss: 0.0448
#
# --5/5 fold--
#
# Epoch 1/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9869 - loss: 0.0326 - val_accuracy: 0.9871 - val_loss: 0.0276
# Epoch 2/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9796 - loss: 0.0715 - val_accuracy: 0.9797 - val_loss: 0.0660
# Epoch 3/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9800 - loss: 0.0507 - val_accuracy: 0.9945 - val_loss: 0.0218
# Epoch 4/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.9919 - loss: 0.0237 - val_accuracy: 0.9889 - val_loss: 0.0280
# Epoch 5/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9921 - loss: 0.0195 - val_accuracy: 0.9760 - val_loss: 0.0789
# Epoch 6/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9968 - loss: 0.0105 - val_accuracy: 0.9779 - val_loss: 0.0668
# Epoch 7/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9980 - loss: 0.0108 - val_accuracy: 0.9908 - val_loss: 0.0318
# Epoch 8/8
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9983 - loss: 0.0030 - val_accuracy: 0.9889 - val_loss: 0.0358
#
# --<Functional name=functional_1837, built=True>--
#
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# Precision: 0.96447
# Recall: 0.92985
# F1 Score: 0.94684
# Accuracy : 0.90560
# ROC AUC Score: 0.80339

# %%
models = [_1DCNN_model, _GRU_model, _BiLSTM_model]
pr = ensemble(models, test_set)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Precision: 0.89545
# Recall: 1.00000
# F1 Score: 0.94484
# Accuracy : 0.85195
# ROC AUC Score: 0.60345
#
# Precision: 0.95273
# Recall: 0.88663
# F1 Score: 0.91849
# Accuracy : 0.73134
# ROC AUC Score: 0.79389
#
# Precision: 0.92985
# Recall: 0.96447
# F1 Score: 0.94684
# Accuracy : 0.80042
# ROC AUC Score: 0.73511
#
# --ensembeld_model--
# Precision: 0.92640
# Recall: 0.97970
# F1 Score: 0.95230
# Accuracy : 0.81357
# ROC AUC Score: 0.72548

# %%
import os
from glob import glob
import warnings
import random
warnings.filterwarnings('ignore')

import import_ipynb
import abuse_detecting_preprocessing as pp
import abuse_detecting_databuild as b

import pandas as pd
import numpy as np

import fasttext

import tensorflow as tf
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, Dropout, BatchNormalization, GRU
from tensorflow.keras.layers import LeakyReLU, Input, Bidirectional, LSTM, GlobalMaxPooling1D, concatenate, ReLU
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import callbacks
from scikeras.wrappers import KerasClassifier

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, precision_recall_curve, roc_curve
from sklearn.model_selection import GridSearchCV

import matplotlib.pyplot as plt
import seaborn as sns

# %%
def seed_everything(seed=0):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
SEED = 30
seed_everything(SEED)

# %%
def print_score(label, pred):
    print('Precision: {:.5f}'.format(precision_score(label, pred)))
    print('Recall: {:.5f}'.format(recall_score(label, pred)))
    print('F1 Score: {:.5f}'.format(f1_score(label, pred)))
    print('Accuracy : {:.5f}'.format(np.mean(label == pred)))
    print('ROC AUC Score: {:.5f}\n'.format(roc_auc_score(label, pred)))

# %%
def _1DCNN(dropout_rate, input_shape):
    
    model = Sequential()
    model.add(Conv1D(filters=64, kernel_size = 6, input_shape = input_shape))
    model.add(LeakyReLU(alpha=0.2))
    # input_shape = (25, 100)
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(dropout_rate))
    
    model.add(Conv1D(filters=128, kernel_size = 3))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(dropout_rate))
    
    model.add(Conv1D(filters=256, kernel_size = 1))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization())
    model.add(GlobalAveragePooling1D())
    model.add(Dropout(dropout_rate))  
    
    model.add(Dense(128))
    model.add(ReLU())
    model.add(Dense(1, activation ='sigmoid'))
    
    model.compile(loss = 'binary_crossentropy',
                  optimizer = 'Adam',
                  metrics = ['accuracy'])
    
    return model

# %%
def combined_pooling_lstm_model(dropout_rate, input_shape):
    
    inputs = Input(shape = input_shape)
    
    # Bidirectional LSTM layer
    x = Bidirectional(LSTM(64, return_sequences = True))(inputs)
    x = Bidirectional(LSTM(64, return_sequences = True))(x)
    
    # Average pool과 Max pool 생성
    avg_pool = GlobalAveragePooling1D()(x)
    max_pool = GlobalMaxPooling1D()(x)
    
    # 두 pool을 합친다.
    combined_pool = concatenate([avg_pool, max_pool])
    combined_pool = BatchNormalization()(combined_pool)
    
    # Dropout
    combined_pool = Dropout(dropout_rate)(combined_pool)
    
    # Output
    outputs = Dense(128)(combined_pool)
    outputs = ReLU()(outputs)
    
    outputs = Dense(1, activation='sigmoid')(outputs)
    
    model = Model(inputs = inputs, outputs = outputs)
    model.compile(loss = "binary_crossentropy",
                  optimizer = 'Adam',
                  metrics = ['accuracy'])
        
    return model

# %%
def GRU_model(dropout_rate, input_shape):
    
    model = Sequential()

    model.add(GRU(128, return_sequences = True, input_shape = input_shape))
    model.add(LeakyReLU(alpha = 0.2))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    model.add(GRU(64, return_sequences = True))
    model.add(LeakyReLU(alpha = 0.2))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    model.add(GRU(32, return_sequences = False))
    model.add(LeakyReLU(alpha = 0.2))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    # output
    model.add(Dense(32))
    model.add(ReLU())
    model.add(Dense(1, activation = 'sigmoid'))
    
    # Model compile
    model.compile(loss = 'binary_crossentropy',
                  optimizer ='Adam',
                  metrics = ['accuracy'])
    
    return model

# %%
def build_train(routes, input_,):
    fasttext_model = fasttext.load_model('/Users/kim-yongjun/Documents/abuse_detecting/fasttext_model.bin')
    
    df = pd.DataFrame()
    for r in routes:
        d = pd.read_csv(r)
        df = pd.concat([df,d], ignore_index = True)

    N = 5
    # df = df[['문장','악플/욕설']]
    # df = df.rename(columns = {'문장' : 'message', '악플/욕설' : 'label'})
    x_train = b.making_x_train(df['message'], input_, fasttext_model, N)
    y_train = np.array(df['label'])
    
    y_train = y_train.astype(np.float32)
    y_train = y_train.reshape(-1,1)
    
    x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, stratify = y_train, random_state = SEED,
                                                       train_size = 0.8, test_size = 0.2)
    print('x_train :', x_train.shape, 'y_train :', y_train.shape)
    print('x_test :', x_test.shape, 'y_test :', y_test.shape)

    return x_train, y_train, x_test, y_test

# %%
def train(model, train_set, k, epochs):
    x_train, y_train = train_set
    # train
    kf = KFold(n_splits = k, shuffle=True)

    for idx, (train_index, val_index) in enumerate(kf.split(x_train)):
        print(f'\n--{idx + 1}/{k} fold--\n')
        
        x_train_fold, x_val_fold = x_train[train_index], x_train[val_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]
        
        model.fit(x_train_fold, y_train_fold, epochs = epochs,
                  validation_data = (x_val_fold, y_val_fold), callbacks = [early_stopping])
        
    print(f'\n--{model}--\n')
    y_pred = np.round(model.predict(x_test))
    print_score(y_pred, y_test)
    
    return model

# %%
def my_GridSearch(model, train_set, param_grid, cv, input_shape, verbose = 0, n_jobs = 5):
    train, y = train_set

    classifier = KerasClassifier(build_fn = model, input_shape = input_shape, dropout_rate = 0.0)
    # GridSearchCV 모델로 초기화
    grid_model = GridSearchCV(estimator = classifier,
                           param_grid = param_grid,
                           scoring = 'roc_auc',
                           cv = cv)
    
    # 모델 fitting
    grid_model.fit(train, y)
    
    # 최적의 하이퍼파라미터 및 점수 출력
    print("Best parameters found: ", grid_model.best_params_)
    print("Best ROC AUC score: ", grid_model.best_score_)
    
    # 결과값 저장
    results = pd.DataFrame(grid_model.cv_results_)
    results = results.sort_values(by='mean_test_score', ascending=False)
    
    return results

# %%
def soft_ensemble(models, test_set):
    x_test, y_test = test_set
    pred = np.column_stack([m.predict(x_test) for m in models])
    ensembled_pred = np.round(np.mean(pred, axis = 1))

    for p in pred.transpose():
        print_score(y_test, np.round(p))
    print('--soft_ensembled_model--')
    print_score(y_test, ensembled_pred)

# %%
def hard_ensemble(models, test_set):
    x_test, y_test = test_set
    l = len(models)
    pred = np.column_stack([np.round(m.predict(x_test)) for m in models])
    ensembled_pred = np.array([1 if np.sum(p) >= 2 else 0 for p in pred])
    # for p in pred.transpose():
    #     print_score(y_test, np.round(p))
    print('--hard_ensembled_model--')
    print_score(y_test, ensembled_pred)

# %%
K = 5
_input = 40 # 단어 길이
input_shape = (_input, 100) # fasttext 모델이 100개의 벡터로 반환함.
dropout_rate = 0.0
early_stopping = EarlyStopping(monitor = 'val_loss', patience = 5) 

data_routes = sorted(glob('chatting_datas/labeled_datas/*.csv'))[:-2]
data_routes.append('chatting_datas/labeled_datas/2024_05_27_13_31_pseudo.csv')
print(data_routes)
# data_routes = glob('/Users/kim-yongjun/Documents/chatting_data/smile_gate_abuse_data/*')
x_train, y_train, x_test, y_test = build_train(data_routes, _input)
train_set = (x_train, y_train)
test_set = (x_test, y_test)
# Out:
# ['chatting_datas/labeled_datas/2024-05-07 18_56_44.182149_labeled_301개.csv', 'chatting_datas/labeled_datas/2024-05-09 17_57_26.245351_labeled_2001개.csv', 'chatting_datas/labeled_datas/2024-05-10 18_22_22.160338_labeled_280개.csv', 'chatting_datas/labeled_datas/2024-05-13 18_29_58.632971_labeled_506개.csv', 'chatting_datas/labeled_datas/2024-05-13 19_02_26.049340_labeled_301개.csv', 'chatting_datas/labeled_datas/2024-05-15 13_57_44.842383_labeled_802개.csv', 'chatting_datas/labeled_datas/2024-05-18 17_35_38.825100_labeled_501개.csv', 'chatting_datas/labeled_datas/2024-05-20 16_32_36.187278_labeled_501개.csv', 'chatting_datas/labeled_datas/2024-05-23 18_50_56.429806_labeled_422개_act.csv', 'chatting_datas/labeled_datas/2024_05_27_13_31_pseudo.csv']
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# x_train : (13648, 40, 100) y_train : (13648, 1)
# x_test : (3413, 40, 100) y_test : (3413, 1)

# %%
cv = 5 # grid_search의 cv

param_grid = {'epochs': [6, 8, 10],
              'dropout_rate': [0.2, 0.3, 0.4]
             }
# 총 90 + 120 + 150 = 360회 수행.

# %%
_1DCNN_grid = my_GridSearch(_1DCNN, train_set, param_grid, cv, input_shape)

# %%
_1DCNN_grid[['rank_test_score', 'params', 'mean_test_score']]
# Out:
#    rank_test_score                               params  mean_test_score
# 7                1   {'dropout_rate': 0.4, 'epochs': 8}         0.833654
# 6                2   {'dropout_rate': 0.4, 'epochs': 6}         0.822915
# 0                3   {'dropout_rate': 0.2, 'epochs': 6}         0.804435
# 8                4  {'dropout_rate': 0.4, 'epochs': 10}         0.801163
# 3                5   {'dropout_rate': 0.3, 'epochs': 6}         0.797306
# 5                6  {'dropout_rate': 0.3, 'epochs': 10}         0.793532
# 2                7  {'dropout_rate': 0.2, 'epochs': 10}         0.791775
# 4                8   {'dropout_rate': 0.3, 'epochs': 8}         0.788748
# 1                9   {'dropout_rate': 0.2, 'epochs': 8}         0.782619

# %%
GRU_grid = my_GridSearch(GRU_model, train_set, param_grid, cv, input_shape)

# %%
GRU_grid[['rank_test_score', 'params', 'mean_test_score']]
# Out:
#    rank_test_score                               params  mean_test_score
# 8                1  {'dropout_rate': 0.4, 'epochs': 10}         0.848118
# 4                2   {'dropout_rate': 0.3, 'epochs': 8}         0.839179
# 5                3  {'dropout_rate': 0.3, 'epochs': 10}         0.836711
# 3                4   {'dropout_rate': 0.3, 'epochs': 6}         0.829297
# 0                5   {'dropout_rate': 0.2, 'epochs': 6}         0.823926
# 7                6   {'dropout_rate': 0.4, 'epochs': 8}         0.822377
# 1                7   {'dropout_rate': 0.2, 'epochs': 8}         0.815840
# 2                8  {'dropout_rate': 0.2, 'epochs': 10}         0.796843
# 6                9   {'dropout_rate': 0.4, 'epochs': 6}         0.783146

# %%
lstm_grid = my_GridSearch(combined_pooling_lstm_model, train_set, param_grid, cv, input_shape)

# %%
# lstm_grid[['rank_test_score', 'params']]
lstm_grid[['rank_test_score', 'params', 'mean_test_score']].reset_index(drop = True)
# Out:
#    rank_test_score                               params  mean_test_score
# 0                1   {'dropout_rate': 0.4, 'epochs': 6}         0.844376
# 1                2  {'dropout_rate': 0.3, 'epochs': 10}         0.836789
# 2                3   {'dropout_rate': 0.2, 'epochs': 8}         0.836439
# 3                4   {'dropout_rate': 0.3, 'epochs': 6}         0.829884
# 4                5   {'dropout_rate': 0.2, 'epochs': 6}         0.823307
# 5                6  {'dropout_rate': 0.2, 'epochs': 10}         0.820952
# 6                7   {'dropout_rate': 0.4, 'epochs': 8}         0.817756
# 7                8  {'dropout_rate': 0.4, 'epochs': 10}         0.808001
# 8                9   {'dropout_rate': 0.3, 'epochs': 8}         0.799347

# %%
# _1DCNN_best = _1DCNN_grid[_1DCNN_grid['rank_test_score'] == 1]['params'].item()
# GRU_best = GRU_grid[GRU_grid['rank_test_score'] == 1]['params'].item()
# BiLSTM_best = lstm_grid[lstm_grid['rank_test_score'] == 1]['params'].item()
_1DCNN_best = {'dropout_rate': 0.4, 'epochs': 8}
GRU_best = {'dropout_rate': 0.4, 'epochs': 10}
BiLSTM_best = {'dropout_rate': 0.4, 'epochs': 6}
_1DCNN_model = _1DCNN(_1DCNN_best['dropout_rate'], input_shape)
_GRU_model =  GRU_model(GRU_best['dropout_rate'], input_shape)
_BiLSTM_model = combined_pooling_lstm_model(BiLSTM_best['dropout_rate'], input_shape)

# %%
_1DCNN_model = train(_1DCNN_model, train_set, K, _1DCNN_best['epochs'])
_GRU_model = train(_GRU_model, train_set, K, GRU_best['epochs'])
_BiLSTM_model = train(_BiLSTM_model, train_set, K, BiLSTM_best['epochs'])
# Out:
# --1/5 fold--
#
# Epoch 1/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7898 - loss: 0.4636 - val_accuracy: 0.8249 - val_loss: 0.4224
# Epoch 2/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8406 - loss: 0.3522 - val_accuracy: 0.8421 - val_loss: 0.3916
# Epoch 3/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8531 - loss: 0.3209 - val_accuracy: 0.8447 - val_loss: 0.3670
# Epoch 4/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8577 - loss: 0.2994 - val_accuracy: 0.8590 - val_loss: 0.3451
# Epoch 5/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8777 - loss: 0.2728 - val_accuracy: 0.8692 - val_loss: 0.3292
# Epoch 6/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8814 - loss: 0.2578 - val_accuracy: 0.8648 - val_loss: 0.3853
# Epoch 7/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8858 - loss: 0.2502 - val_accuracy: 0.8626 - val_loss: 0.4164
# Epoch 8/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8994 - loss: 0.2291 - val_accuracy: 0.8586 - val_loss: 0.4942
#
# --2/5 fold--
#
# Epoch 1/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8933 - loss: 0.2501 - val_accuracy: 0.8982 - val_loss: 0.2303
# Epoch 2/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9042 - loss: 0.2252 - val_accuracy: 0.8960 - val_loss: 0.2346
# Epoch 3/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9059 - loss: 0.2177 - val_accuracy: 0.8952 - val_loss: 0.2518
# Epoch 4/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9096 - loss: 0.1998 - val_accuracy: 0.8868 - val_loss: 0.3019
# Epoch 5/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9208 - loss: 0.1929 - val_accuracy: 0.8952 - val_loss: 0.2843
# Epoch 6/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9239 - loss: 0.1780 - val_accuracy: 0.8846 - val_loss: 0.3833
#
# --3/5 fold--
#
# Epoch 1/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9080 - loss: 0.2217 - val_accuracy: 0.8989 - val_loss: 0.2348
# Epoch 2/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9106 - loss: 0.2030 - val_accuracy: 0.8813 - val_loss: 0.3390
# Epoch 3/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9182 - loss: 0.1888 - val_accuracy: 0.8842 - val_loss: 0.3042
# Epoch 4/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9275 - loss: 0.1758 - val_accuracy: 0.8919 - val_loss: 0.3086
# Epoch 5/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9278 - loss: 0.1689 - val_accuracy: 0.8755 - val_loss: 0.4271
#
# --4/5 fold--
#
# Epoch 1/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9183 - loss: 0.1941 - val_accuracy: 0.9366 - val_loss: 0.1374
# Epoch 2/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9279 - loss: 0.1727 - val_accuracy: 0.9249 - val_loss: 0.1779
# Epoch 3/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9340 - loss: 0.1589 - val_accuracy: 0.9139 - val_loss: 0.1911
# Epoch 4/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9356 - loss: 0.1541 - val_accuracy: 0.9187 - val_loss: 0.2358
# Epoch 5/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9439 - loss: 0.1441 - val_accuracy: 0.9124 - val_loss: 0.2606
# Epoch 6/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9440 - loss: 0.1409 - val_accuracy: 0.9117 - val_loss: 0.2392
#
# --5/5 fold--
#
# Epoch 1/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9312 - loss: 0.1645 - val_accuracy: 0.9322 - val_loss: 0.1409
# Epoch 2/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9399 - loss: 0.1488 - val_accuracy: 0.9421 - val_loss: 0.1299
# Epoch 3/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9388 - loss: 0.1468 - val_accuracy: 0.9216 - val_loss: 0.1993
# Epoch 4/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9448 - loss: 0.1368 - val_accuracy: 0.9179 - val_loss: 0.2239
# Epoch 5/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9525 - loss: 0.1228 - val_accuracy: 0.9190 - val_loss: 0.2181
# Epoch 6/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9496 - loss: 0.1226 - val_accuracy: 0.9351 - val_loss: 0.1818
# Epoch 7/8
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9484 - loss: 0.1269 - val_accuracy: 0.9110 - val_loss: 0.2546
#
# --<Sequential name=sequential_8, built=True>--
#
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Precision: 0.98322
# Recall: 0.87362
# F1 Score: 0.92519
# Accuracy : 0.87225
# ROC AUC Score: 0.86648
#
#
# --1/5 fold--
#
# Epoch 1/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.7763 - loss: 0.5194 - val_accuracy: 0.8007 - val_loss: 0.4471
# Epoch 2/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 12s 36ms/step - accuracy: 0.7905 - loss: 0.4504 - val_accuracy: 0.6161 - val_loss: 0.4960
# Epoch 3/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 12s 36ms/step - accuracy: 0.8191 - loss: 0.3793 - val_accuracy: 0.8751 - val_loss: 0.2985
# Epoch 4/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.8488 - loss: 0.3266 - val_accuracy: 0.8806 - val_loss: 0.2790
# Epoch 5/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 12s 36ms/step - accuracy: 0.8641 - loss: 0.2942 - val_accuracy: 0.8780 - val_loss: 0.2778
#
# --2/5 fold--
#
# Epoch 1/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 12s 36ms/step - accuracy: 0.8780 - loss: 0.2695 - val_accuracy: 0.8722 - val_loss: 0.2640
# Epoch 2/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.8934 - loss: 0.2435 - val_accuracy: 0.8927 - val_loss: 0.2424
# Epoch 3/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.8998 - loss: 0.2294 - val_accuracy: 0.8872 - val_loss: 0.2538
# Epoch 4/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 12s 36ms/step - accuracy: 0.9088 - loss: 0.2176 - val_accuracy: 0.8747 - val_loss: 0.2855
# Epoch 5/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 12s 36ms/step - accuracy: 0.9175 - loss: 0.1988 - val_accuracy: 0.8890 - val_loss: 0.2694
#
# --3/5 fold--
#
# Epoch 1/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 12s 36ms/step - accuracy: 0.9199 - loss: 0.1951 - val_accuracy: 0.9055 - val_loss: 0.2209
# Epoch 2/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.9245 - loss: 0.1807 - val_accuracy: 0.8326 - val_loss: 0.3930
# Epoch 3/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.9297 - loss: 0.1696 - val_accuracy: 0.9136 - val_loss: 0.2144
# Epoch 4/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.9475 - loss: 0.1398 - val_accuracy: 0.9059 - val_loss: 0.2342
# Epoch 5/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.9519 - loss: 0.1274 - val_accuracy: 0.8886 - val_loss: 0.2977
#
# --4/5 fold--
#
# Epoch 1/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.9378 - loss: 0.1590 - val_accuracy: 0.9590 - val_loss: 0.1126
# Epoch 2/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.9535 - loss: 0.1207 - val_accuracy: 0.9458 - val_loss: 0.1277
# Epoch 3/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.9583 - loss: 0.1106 - val_accuracy: 0.9351 - val_loss: 0.1808
# Epoch 4/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.9671 - loss: 0.0970 - val_accuracy: 0.9458 - val_loss: 0.1453
# Epoch 5/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.9712 - loss: 0.0792 - val_accuracy: 0.9373 - val_loss: 0.1714
# Epoch 6/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.9745 - loss: 0.0752 - val_accuracy: 0.9425 - val_loss: 0.1629
#
# --5/5 fold--
#
# Epoch 1/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.9601 - loss: 0.1124 - val_accuracy: 0.9806 - val_loss: 0.0664
# Epoch 2/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.9678 - loss: 0.0896 - val_accuracy: 0.9795 - val_loss: 0.0579
# Epoch 3/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.9757 - loss: 0.0752 - val_accuracy: 0.9740 - val_loss: 0.0695
# Epoch 4/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.9777 - loss: 0.0698 - val_accuracy: 0.9725 - val_loss: 0.0830
# Epoch 5/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.9756 - loss: 0.0698 - val_accuracy: 0.9736 - val_loss: 0.0704
# Epoch 6/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.9793 - loss: 0.0621 - val_accuracy: 0.9612 - val_loss: 0.1026
# Epoch 7/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.9828 - loss: 0.0511 - val_accuracy: 0.9524 - val_loss: 0.1358
#
# --<Sequential name=sequential_9, built=True>--
#
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# Precision: 0.95842
# Recall: 0.90809
# F1 Score: 0.93258
# Accuracy : 0.88866
# ROC AUC Score: 0.84422
#
#
# --1/5 fold--
#
# Epoch 1/6
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 15s 35ms/step - accuracy: 0.7951 - loss: 0.4343 - val_accuracy: 0.8212 - val_loss: 0.3445
# Epoch 2/6
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - accuracy: 0.8610 - loss: 0.3046 - val_accuracy: 0.8744 - val_loss: 0.2956
# Epoch 3/6
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8776 - loss: 0.2704 - val_accuracy: 0.8842 - val_loss: 0.2678
# Epoch 4/6
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.8979 - loss: 0.2327 - val_accuracy: 0.8824 - val_loss: 0.2664
# Epoch 5/6
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - accuracy: 0.9091 - loss: 0.2087 - val_accuracy: 0.8799 - val_loss: 0.2972
#
# --2/5 fold--
#
# Epoch 1/6
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - accuracy: 0.9118 - loss: 0.2144 - val_accuracy: 0.9370 - val_loss: 0.1657
# Epoch 2/6
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - accuracy: 0.9210 - loss: 0.1787 - val_accuracy: 0.9341 - val_loss: 0.1713
# Epoch 3/6
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - accuracy: 0.9348 - loss: 0.1505 - val_accuracy: 0.9286 - val_loss: 0.1650
# Epoch 4/6
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - accuracy: 0.9480 - loss: 0.1265 - val_accuracy: 0.9264 - val_loss: 0.2266
# Epoch 5/6
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - accuracy: 0.9564 - loss: 0.1061 - val_accuracy: 0.9154 - val_loss: 0.2597
#
# --3/5 fold--
#
# Epoch 1/6
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - accuracy: 0.9439 - loss: 0.1457 - val_accuracy: 0.9707 - val_loss: 0.0811
# Epoch 2/6
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - accuracy: 0.9641 - loss: 0.0895 - val_accuracy: 0.9557 - val_loss: 0.1037
# Epoch 3/6
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - accuracy: 0.9716 - loss: 0.0711 - val_accuracy: 0.9535 - val_loss: 0.1183
# Epoch 4/6
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - accuracy: 0.9778 - loss: 0.0583 - val_accuracy: 0.9546 - val_loss: 0.1120
# Epoch 5/6
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - accuracy: 0.9826 - loss: 0.0511 - val_accuracy: 0.9509 - val_loss: 0.1391
#
# --4/5 fold--
#
# Epoch 1/6
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.9612 - loss: 0.1014 - val_accuracy: 0.9780 - val_loss: 0.0633
# Epoch 2/6
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - accuracy: 0.9753 - loss: 0.0617 - val_accuracy: 0.9718 - val_loss: 0.0719
# Epoch 3/6
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - accuracy: 0.9837 - loss: 0.0478 - val_accuracy: 0.9663 - val_loss: 0.1021
# Epoch 4/6
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - accuracy: 0.9800 - loss: 0.0548 - val_accuracy: 0.9619 - val_loss: 0.0998
# Epoch 5/6
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - accuracy: 0.9865 - loss: 0.0361 - val_accuracy: 0.9593 - val_loss: 0.1205
#
# --5/5 fold--
#
# Epoch 1/6
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.9695 - loss: 0.0787 - val_accuracy: 0.9908 - val_loss: 0.0313
# Epoch 2/6
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.9831 - loss: 0.0436 - val_accuracy: 0.9784 - val_loss: 0.0597
# Epoch 3/6
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.9879 - loss: 0.0366 - val_accuracy: 0.9736 - val_loss: 0.0943
# Epoch 4/6
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.9919 - loss: 0.0236 - val_accuracy: 0.9846 - val_loss: 0.0386
# Epoch 5/6
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.9916 - loss: 0.0280 - val_accuracy: 0.9850 - val_loss: 0.0416
# Epoch 6/6
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.9894 - loss: 0.0310 - val_accuracy: 0.9787 - val_loss: 0.0618
#
# --<Functional name=functional_174, built=True>--
#
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Precision: 0.91794
# Recall: 0.93222
# F1 Score: 0.92503
# Accuracy : 0.88046
# ROC AUC Score: 0.80833

# %%
models = [_1DCNN_model, _GRU_model, _BiLSTM_model]
soft_ensemble(models, test_set)
hard_ensemble(models, test_set)
# Out:
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# Precision: 0.87362
# Recall: 0.98322
# F1 Score: 0.92519
# Accuracy : 0.74526
# ROC AUC Score: 0.70100
#
# Precision: 0.90809
# Recall: 0.95842
# F1 Score: 0.93258
# Accuracy : 0.71113
# ROC AUC Score: 0.78100
#
# Precision: 0.93222
# Recall: 0.91794
# F1 Score: 0.92503
# Accuracy : 0.67663
# ROC AUC Score: 0.82261
#
# --soft_ensembled_model--
# Precision: 0.90693
# Recall: 0.97374
# F1 Score: 0.93915
# Accuracy : 0.72002
# ROC AUC Score: 0.78270
#
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# --hard_ensembled_model--
# Precision: 0.90407
# Recall: 0.97265
# F1 Score: 0.93710
# Accuracy : 0.72108
# ROC AUC Score: 0.77544

# %%
_1DCNN_model.save('1DCNN_model.h5')
_GRU_model.save('GRU_model.h5')
_BiLSTM_model.save('BiLSTM_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

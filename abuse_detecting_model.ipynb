# %%
import os
from glob import glob
import warnings
import random
warnings.filterwarnings('ignore')

import import_ipynb
import abuse_detecting_preprocessing as pp
import abuse_detecting_databuild as b

import pandas as pd
import numpy as np

import fasttext

import tensorflow as tf
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, Dropout, BatchNormalization, GRU
from tensorflow.keras.layers import LeakyReLU, Input, Bidirectional, LSTM, GlobalMaxPooling1D, concatenate, ReLU
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import callbacks
from scikeras.wrappers import KerasClassifier

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, precision_recall_curve, roc_curve
from sklearn.model_selection import GridSearchCV

import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# importing Jupyter notebook from abuse_detecting_preprocessing.ipynb
# ['ㅇㅡㄴㄹㅡㄹㅈㅏㄹㅇㅣ-ㄱㅣㄴㄷㅏ-ㅎㅏ-', 'ㄴㅡㄴㄹㅗㄹㅇㅢ-ㅅㅣㄴㅇㅣ-ㄷㅏ-']
#
# ['t1ㅇㅡㄴlckㄹㅡㄹㅈㅏㄹㅇㅣ-ㄱㅣㄴㄷㅏ-ㅎㅏ-', 'fakerㄴㅡㄴㄹㅗㄹㅇㅢ-ㅅㅣㄴㅇㅣ-ㄷㅏ-']
#
# importing Jupyter notebook from abuse_detecting_databuild.ipynb
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
def seed_everything(seed=0):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
SEED = 30
seed_everything(SEED)

# %%
def print_score(label, pred):
    print('Precision: {:.5f}'.format(precision_score(label, pred)))
    print('Recall: {:.5f}'.format(recall_score(label, pred)))
    print('F1 Score: {:.5f}'.format(f1_score(label, pred)))
    print('Accuracy : {:.5f}'.format(np.mean(label == pred)))
    print('ROC AUC Score: {:.5f}\n'.format(roc_auc_score(label, pred)))

# %%
def _1DCNN(dropout_rate, input_shape):
    
    model = Sequential()
    model.add(Conv1D(filters=64, kernel_size = 6, input_shape = input_shape))
    model.add(LeakyReLU(alpha=0.2))
    # input_shape = (25, 100)
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(dropout_rate))
    
    model.add(Conv1D(filters=128, kernel_size = 3))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(dropout_rate))
    
    model.add(Conv1D(filters=256, kernel_size = 1))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization())
    model.add(GlobalAveragePooling1D())
    model.add(Dropout(dropout_rate))  
    
    model.add(Dense(128))
    model.add(ReLU())
    model.add(Dense(1, activation ='sigmoid'))
    
    model.compile(loss = 'binary_crossentropy',
                  optimizer = 'Adam',
                  metrics = ['accuracy'])
    
    return model

# %%
def combined_pooling_lstm_model(dropout_rate, input_shape):
    
    inputs = Input(shape = input_shape)
    
    # Bidirectional LSTM layer
    x = Bidirectional(LSTM(64, return_sequences = True))(inputs)
    x = Bidirectional(LSTM(64, return_sequences = True))(x)
    
    # Average pool과 Max pool 생성
    avg_pool = GlobalAveragePooling1D()(x)
    max_pool = GlobalMaxPooling1D()(x)
    
    # 두 pool을 합친다.
    combined_pool = concatenate([avg_pool, max_pool])
    combined_pool = BatchNormalization()(combined_pool)
    
    # Dropout
    combined_pool = Dropout(dropout_rate)(combined_pool)
    
    # Output
    outputs = Dense(128)(combined_pool)
    outputs = ReLU()(outputs)
    
    outputs = Dense(1, activation='sigmoid')(outputs)
    
    model = Model(inputs = inputs, outputs = outputs)
    model.compile(loss = "binary_crossentropy",
                  optimizer = 'Adam',
                  metrics = ['accuracy'])
        
    return model

# %%
def GRU_model(dropout_rate, input_shape):
    
    model = Sequential()

    model.add(GRU(128, return_sequences = True, input_shape = input_shape))
    model.add(LeakyReLU(alpha = 0.2))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    model.add(GRU(64, return_sequences = True))
    model.add(LeakyReLU(alpha = 0.2))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    model.add(GRU(32, return_sequences = False))
    model.add(LeakyReLU(alpha = 0.2))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    # output
    model.add(Dense(32))
    model.add(ReLU())
    model.add(Dense(1, activation = 'sigmoid'))
    
    # Model compile
    model.compile(loss = 'binary_crossentropy',
                  optimizer ='Adam',
                  metrics = ['accuracy'])
    
    return model

# %%
def build_train(routes, input_,):
    fasttext_model = fasttext.load_model('/Users/kim-yongjun/Documents/abuse_detecting/fasttext_model.bin')
    
    df = pd.DataFrame()
    for r in routes:
        d = pd.read_csv(r)
        df = pd.concat([df,d], ignore_index = True)

    N = 5
    # df = df[['문장','악플/욕설']]
    # df = df.rename(columns = {'문장' : 'message', '악플/욕설' : 'label'})
    x_train = b.making_x_train(df['message'], input_, fasttext_model, N)
    y_train = np.array(df['label'])
    
    y_train = y_train.astype(np.float32)
    y_train = y_train.reshape(-1,1)
    
    x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, stratify = y_train, random_state = SEED,
                                                       train_size = 0.8, test_size = 0.2)
    print('x_train :', x_train.shape, 'y_train :', y_train.shape)
    print('x_test :', x_test.shape, 'y_test :', y_test.shape)

    return x_train, y_train, x_test, y_test

# %%
def train(model, train_set, k, epochs):
    x_train, y_train = train_set
    # train
    kf = KFold(n_splits = k, shuffle=True)

    for idx, (train_index, val_index) in enumerate(kf.split(x_train)):
        print(f'\n--{idx + 1}/{k} fold--\n')
        
        x_train_fold, x_val_fold = x_train[train_index], x_train[val_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]
        
        model.fit(x_train_fold, y_train_fold, epochs = epochs,
                  validation_data = (x_val_fold, y_val_fold), callbacks = [early_stopping])
        
    print(f'\n--{model}--\n')
    y_pred = np.round(model.predict(x_test))
    print_score(y_pred, y_test)
    
    return model

# %%
def my_GridSearch(model, train_set, param_grid, cv, input_shape, verbose = 0, n_jobs = 5):
    train, y = train_set

    classifier = KerasClassifier(build_fn = model, input_shape = input_shape, dropout_rate = 0.0)
    # GridSearchCV 모델로 초기화
    grid_model = GridSearchCV(estimator = classifier,
                           param_grid = param_grid,
                           scoring = 'roc_auc',
                           cv = cv)
    
    # 모델 fitting
    grid_model.fit(train, y)
    
    # 최적의 하이퍼파라미터 및 점수 출력
    print("Best parameters found: ", grid_model.best_params_)
    print("Best ROC AUC score: ", grid_model.best_score_)
    
    # 결과값 저장
    results = pd.DataFrame(grid_model.cv_results_)
    results = results.sort_values(by='mean_test_score', ascending=False)
    
    return results

# %%
def soft_ensemble(models, test_set):
    x_test, y_test = test_set
    pred = np.column_stack([m.predict(x_test) for m in models])
    ensembled_pred = np.round(np.mean(pred, axis = 1))

    for p in pred.transpose():
        print_score(y_test, np.round(p))
    print('--soft_ensembled_model--')
    print_score(y_test, ensembled_pred)

# %%
def hard_ensemble(models, test_set):
    x_test, y_test = test_set
    l = len(models)
    pred = np.column_stack([np.round(m.predict(x_test)) for m in models])
    ensembled_pred = np.array([1 if np.sum(p) >= 2 else 0 for p in pred])
    # for p in pred.transpose():
    #     print_score(y_test, np.round(p))
    print('--hard_ensembled_model--')
    print_score(y_test, ensembled_pred)

# %%
K = 5
_input = 40 # 단어 길이
input_shape = (_input, 100) # fasttext 모델이 100개의 벡터로 반환함.
dropout_rate = 0.0
early_stopping = EarlyStopping(monitor = 'val_loss', patience = 5) 

data_routes = sorted(glob('chatting_datas/labeled_datas/*.csv'))
# data_routes.append('chatting_datas/labeled_datas/2024_05_27_13_31_pseudo.csv')
# data_routes = glob('/Users/kim-yongjun/Documents/chatting_data/smile_gate_abuse_data/*')
x_train, y_train, x_test, y_test = build_train(data_routes, _input)
train_set = (x_train, y_train)
test_set = (x_test, y_test)
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# x_train : (29636, 40, 100) y_train : (29636, 1)
# x_test : (7409, 40, 100) y_test : (7409, 1)

# %%
cv = 5 # grid_search의 cv

param_grid = {'epochs': [6, 8, 10],
              'dropout_rate': [0.2, 0.3, 0.4]
             }
# 총 90 + 120 + 150 = 360회 수행.

# %%
_1DCNN_grid = my_GridSearch(_1DCNN, train_set, param_grid, cv, input_shape)

# %%
_1DCNN_grid[['rank_test_score', 'params', 'mean_test_score']]
# Out:
#    rank_test_score                               params  mean_test_score
# 7                1   {'dropout_rate': 0.4, 'epochs': 8}         0.833654
# 6                2   {'dropout_rate': 0.4, 'epochs': 6}         0.822915
# 0                3   {'dropout_rate': 0.2, 'epochs': 6}         0.804435
# 8                4  {'dropout_rate': 0.4, 'epochs': 10}         0.801163
# 3                5   {'dropout_rate': 0.3, 'epochs': 6}         0.797306
# 5                6  {'dropout_rate': 0.3, 'epochs': 10}         0.793532
# 2                7  {'dropout_rate': 0.2, 'epochs': 10}         0.791775
# 4                8   {'dropout_rate': 0.3, 'epochs': 8}         0.788748
# 1                9   {'dropout_rate': 0.2, 'epochs': 8}         0.782619

# %%
GRU_grid = my_GridSearch(GRU_model, train_set, param_grid, cv, input_shape)

# %%
GRU_grid[['rank_test_score', 'params', 'mean_test_score']]
# Out:
#    rank_test_score                               params  mean_test_score
# 8                1  {'dropout_rate': 0.4, 'epochs': 10}         0.848118
# 4                2   {'dropout_rate': 0.3, 'epochs': 8}         0.839179
# 5                3  {'dropout_rate': 0.3, 'epochs': 10}         0.836711
# 3                4   {'dropout_rate': 0.3, 'epochs': 6}         0.829297
# 0                5   {'dropout_rate': 0.2, 'epochs': 6}         0.823926
# 7                6   {'dropout_rate': 0.4, 'epochs': 8}         0.822377
# 1                7   {'dropout_rate': 0.2, 'epochs': 8}         0.815840
# 2                8  {'dropout_rate': 0.2, 'epochs': 10}         0.796843
# 6                9   {'dropout_rate': 0.4, 'epochs': 6}         0.783146

# %%
lstm_grid = my_GridSearch(combined_pooling_lstm_model, train_set, param_grid, cv, input_shape)

# %%
# lstm_grid[['rank_test_score', 'params']]
lstm_grid[['rank_test_score', 'params', 'mean_test_score']].reset_index(drop = True)
# Out:
#    rank_test_score                               params  mean_test_score
# 0                1   {'dropout_rate': 0.4, 'epochs': 6}         0.844376
# 1                2  {'dropout_rate': 0.3, 'epochs': 10}         0.836789
# 2                3   {'dropout_rate': 0.2, 'epochs': 8}         0.836439
# 3                4   {'dropout_rate': 0.3, 'epochs': 6}         0.829884
# 4                5   {'dropout_rate': 0.2, 'epochs': 6}         0.823307
# 5                6  {'dropout_rate': 0.2, 'epochs': 10}         0.820952
# 6                7   {'dropout_rate': 0.4, 'epochs': 8}         0.817756
# 7                8  {'dropout_rate': 0.4, 'epochs': 10}         0.808001
# 8                9   {'dropout_rate': 0.3, 'epochs': 8}         0.799347

# %%
# _1DCNN_best = _1DCNN_grid[_1DCNN_grid['rank_test_score'] == 1]['params'].item()
# GRU_best = GRU_grid[GRU_grid['rank_test_score'] == 1]['params'].item()
# BiLSTM_best = lstm_grid[lstm_grid['rank_test_score'] == 1]['params'].item()
_1DCNN_best = {'dropout_rate': 0.4, 'epochs': 8}
GRU_best = {'dropout_rate': 0.4, 'epochs': 10}
BiLSTM_best = {'dropout_rate': 0.4, 'epochs': 6}
_1DCNN_model = _1DCNN(_1DCNN_best['dropout_rate'], input_shape)
_GRU_model =  GRU_model(GRU_best['dropout_rate'], input_shape)
_BiLSTM_model = combined_pooling_lstm_model(BiLSTM_best['dropout_rate'], input_shape)

# %%
_1DCNN_model = train(_1DCNN_model, train_set, K, _1DCNN_best['epochs'])
_GRU_model = train(_GRU_model, train_set, K, GRU_best['epochs'])
_BiLSTM_model = train(_BiLSTM_model, train_set, K, BiLSTM_best['epochs'])
# Out:
# --1/5 fold--
#
# Epoch 1/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9288 - loss: 0.2241 - val_accuracy: 0.9470 - val_loss: 0.1727
# Epoch 2/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9540 - loss: 0.1410 - val_accuracy: 0.9509 - val_loss: 0.1765
# Epoch 3/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9580 - loss: 0.1273 - val_accuracy: 0.9523 - val_loss: 0.1602
# Epoch 4/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9610 - loss: 0.1185 - val_accuracy: 0.9523 - val_loss: 0.1761
# Epoch 5/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9621 - loss: 0.1094 - val_accuracy: 0.9533 - val_loss: 0.1871
# Epoch 6/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9632 - loss: 0.1072 - val_accuracy: 0.9572 - val_loss: 0.1631
# Epoch 7/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9670 - loss: 0.0986 - val_accuracy: 0.9570 - val_loss: 0.1852
# Epoch 8/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9670 - loss: 0.0948 - val_accuracy: 0.9555 - val_loss: 0.2069
#
# --2/5 fold--
#
# Epoch 1/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9656 - loss: 0.1044 - val_accuracy: 0.9738 - val_loss: 0.0739
# Epoch 2/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9669 - loss: 0.0974 - val_accuracy: 0.9683 - val_loss: 0.0926
# Epoch 3/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9675 - loss: 0.0925 - val_accuracy: 0.9718 - val_loss: 0.0890
# Epoch 4/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9696 - loss: 0.0868 - val_accuracy: 0.9708 - val_loss: 0.0987
# Epoch 5/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9715 - loss: 0.0835 - val_accuracy: 0.9688 - val_loss: 0.1190
# Epoch 6/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9712 - loss: 0.0813 - val_accuracy: 0.9698 - val_loss: 0.1363
#
# --3/5 fold--
#
# Epoch 1/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9706 - loss: 0.0833 - val_accuracy: 0.9671 - val_loss: 0.0890
# Epoch 2/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9709 - loss: 0.0805 - val_accuracy: 0.9679 - val_loss: 0.0933
# Epoch 3/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9736 - loss: 0.0734 - val_accuracy: 0.9673 - val_loss: 0.1062
# Epoch 4/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9729 - loss: 0.0717 - val_accuracy: 0.9654 - val_loss: 0.1253
# Epoch 5/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9737 - loss: 0.0703 - val_accuracy: 0.9656 - val_loss: 0.1259
#
# --4/5 fold--
#
# Epoch 1/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9720 - loss: 0.0821 - val_accuracy: 0.9718 - val_loss: 0.0747
# Epoch 2/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9737 - loss: 0.0733 - val_accuracy: 0.9696 - val_loss: 0.0885
# Epoch 3/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9729 - loss: 0.0682 - val_accuracy: 0.9728 - val_loss: 0.0891
# Epoch 4/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9769 - loss: 0.0649 - val_accuracy: 0.9679 - val_loss: 0.1130
# Epoch 5/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9765 - loss: 0.0615 - val_accuracy: 0.9703 - val_loss: 0.1045
#
# --5/5 fold--
#
# Epoch 1/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9741 - loss: 0.0693 - val_accuracy: 0.9750 - val_loss: 0.0536
# Epoch 2/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9775 - loss: 0.0609 - val_accuracy: 0.9769 - val_loss: 0.0604
# Epoch 3/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9789 - loss: 0.0598 - val_accuracy: 0.9744 - val_loss: 0.0740
# Epoch 4/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9800 - loss: 0.0571 - val_accuracy: 0.9750 - val_loss: 0.0715
# Epoch 5/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9791 - loss: 0.0570 - val_accuracy: 0.9737 - val_loss: 0.0842
# Epoch 6/8
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9790 - loss: 0.0547 - val_accuracy: 0.9742 - val_loss: 0.0838
#
# --<Sequential name=sequential, built=True>--
#
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Precision: 0.99347
# Recall: 0.96871
# F1 Score: 0.98093
# Accuracy : 0.96410
# ROC AUC Score: 0.91951
#
#
# --1/5 fold--
#
# Epoch 1/10
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.9139 - loss: 0.3042 - val_accuracy: 0.9533 - val_loss: 0.1905
# Epoch 2/10
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 26s 36ms/step - accuracy: 0.9382 - loss: 0.1863 - val_accuracy: 0.9637 - val_loss: 0.1247
# Epoch 3/10
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 26s 36ms/step - accuracy: 0.9534 - loss: 0.1474 - val_accuracy: 0.9550 - val_loss: 0.1251
# Epoch 4/10
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 26s 36ms/step - accuracy: 0.9579 - loss: 0.1323 - val_accuracy: 0.9570 - val_loss: 0.1274
# Epoch 5/10
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 26s 36ms/step - accuracy: 0.9631 - loss: 0.1209 - val_accuracy: 0.9644 - val_loss: 0.1149
#
# --2/5 fold--
#
# Epoch 1/10
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 27s 36ms/step - accuracy: 0.9634 - loss: 0.1210 - val_accuracy: 0.9641 - val_loss: 0.1104
# Epoch 2/10
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 26s 35ms/step - accuracy: 0.9652 - loss: 0.1141 - val_accuracy: 0.9631 - val_loss: 0.1167
# Epoch 3/10
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 26s 36ms/step - accuracy: 0.9658 - loss: 0.1063 - val_accuracy: 0.9634 - val_loss: 0.1323
# Epoch 4/10
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 27s 37ms/step - accuracy: 0.9681 - loss: 0.1018 - val_accuracy: 0.9647 - val_loss: 0.1212
# Epoch 5/10
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 26s 35ms/step - accuracy: 0.9686 - loss: 0.0971 - val_accuracy: 0.9636 - val_loss: 0.1237
#
# --3/5 fold--
#
# Epoch 1/10
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 27s 36ms/step - accuracy: 0.9706 - loss: 0.0925 - val_accuracy: 0.9678 - val_loss: 0.0898
# Epoch 2/10
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 26s 35ms/step - accuracy: 0.9740 - loss: 0.0812 - val_accuracy: 0.9632 - val_loss: 0.0980
# Epoch 3/10
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 27s 36ms/step - accuracy: 0.9751 - loss: 0.0743 - val_accuracy: 0.9663 - val_loss: 0.1095
# Epoch 4/10
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 26s 36ms/step - accuracy: 0.9772 - loss: 0.0674 - val_accuracy: 0.9615 - val_loss: 0.1113
# Epoch 5/10
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 27s 36ms/step - accuracy: 0.9786 - loss: 0.0638 - val_accuracy: 0.9607 - val_loss: 0.1226
#
# --4/5 fold--
#
# Epoch 1/10
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 27s 36ms/step - accuracy: 0.9757 - loss: 0.0786 - val_accuracy: 0.9747 - val_loss: 0.0682
# Epoch 2/10
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 27s 36ms/step - accuracy: 0.9780 - loss: 0.0702 - val_accuracy: 0.9794 - val_loss: 0.0599
# Epoch 3/10
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 27s 36ms/step - accuracy: 0.9803 - loss: 0.0638 - val_accuracy: 0.9747 - val_loss: 0.0677
# Epoch 4/10
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 27s 36ms/step - accuracy: 0.9816 - loss: 0.0593 - val_accuracy: 0.9718 - val_loss: 0.0766
# Epoch 5/10
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 26s 36ms/step - accuracy: 0.9822 - loss: 0.0542 - val_accuracy: 0.9691 - val_loss: 0.0817
#
# --5/5 fold--
#
# Epoch 1/10
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 27s 36ms/step - accuracy: 0.9805 - loss: 0.0609 - val_accuracy: 0.9870 - val_loss: 0.0389
# Epoch 2/10
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 27s 36ms/step - accuracy: 0.9830 - loss: 0.0537 - val_accuracy: 0.9857 - val_loss: 0.0423
# Epoch 3/10
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 27s 36ms/step - accuracy: 0.9861 - loss: 0.0483 - val_accuracy: 0.9848 - val_loss: 0.0451
# Epoch 4/10
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 27s 36ms/step - accuracy: 0.9859 - loss: 0.0425 - val_accuracy: 0.9853 - val_loss: 0.0446
# Epoch 5/10
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 27s 36ms/step - accuracy: 0.9899 - loss: 0.0360 - val_accuracy: 0.9796 - val_loss: 0.0653
# Epoch 6/10
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 27s 36ms/step - accuracy: 0.9876 - loss: 0.0376 - val_accuracy: 0.9830 - val_loss: 0.0584
#
# --<Sequential name=sequential_1, built=True>--
#
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
# Precision: 0.98374
# Recall: 0.97090
# F1 Score: 0.97728
# Accuracy : 0.95748
# ROC AUC Score: 0.85582
#
#
# --1/5 fold--
#
# Epoch 1/6
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.9286 - loss: 0.2072 - val_accuracy: 0.9543 - val_loss: 0.1468
# Epoch 2/6
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 31s 41ms/step - accuracy: 0.9614 - loss: 0.1259 - val_accuracy: 0.9561 - val_loss: 0.1491
# Epoch 3/6
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 30s 41ms/step - accuracy: 0.9649 - loss: 0.1082 - val_accuracy: 0.9582 - val_loss: 0.1453
# Epoch 4/6
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 30s 41ms/step - accuracy: 0.9674 - loss: 0.0954 - val_accuracy: 0.9592 - val_loss: 0.1465
# Epoch 5/6
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 30s 41ms/step - accuracy: 0.9696 - loss: 0.0867 - val_accuracy: 0.9575 - val_loss: 0.1357
#
# --2/5 fold--
#
# Epoch 1/6
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 31s 41ms/step - accuracy: 0.9652 - loss: 0.1009 - val_accuracy: 0.9728 - val_loss: 0.0808
# Epoch 2/6
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 31s 41ms/step - accuracy: 0.9698 - loss: 0.0809 - val_accuracy: 0.9740 - val_loss: 0.0850
# Epoch 3/6
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 31s 42ms/step - accuracy: 0.9725 - loss: 0.0696 - val_accuracy: 0.9717 - val_loss: 0.1011
# Epoch 4/6
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 30s 41ms/step - accuracy: 0.9766 - loss: 0.0568 - val_accuracy: 0.9703 - val_loss: 0.1129
# Epoch 5/6
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 30s 41ms/step - accuracy: 0.9815 - loss: 0.0470 - val_accuracy: 0.9695 - val_loss: 0.1427
#
# --3/5 fold--
#
# Epoch 1/6
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 30s 41ms/step - accuracy: 0.9755 - loss: 0.0668 - val_accuracy: 0.9825 - val_loss: 0.0495
# Epoch 2/6
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 30s 41ms/step - accuracy: 0.9815 - loss: 0.0466 - val_accuracy: 0.9803 - val_loss: 0.0515
# Epoch 3/6
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 31s 41ms/step - accuracy: 0.9856 - loss: 0.0382 - val_accuracy: 0.9774 - val_loss: 0.0771
# Epoch 4/6
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 30s 41ms/step - accuracy: 0.9878 - loss: 0.0341 - val_accuracy: 0.9711 - val_loss: 0.0894
# Epoch 5/6
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 30s 41ms/step - accuracy: 0.9878 - loss: 0.0327 - val_accuracy: 0.9730 - val_loss: 0.1015
#
# --4/5 fold--
#
# Epoch 1/6
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 30s 41ms/step - accuracy: 0.9814 - loss: 0.0482 - val_accuracy: 0.9902 - val_loss: 0.0317
# Epoch 2/6
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 31s 41ms/step - accuracy: 0.9907 - loss: 0.0245 - val_accuracy: 0.9862 - val_loss: 0.0448
# Epoch 3/6
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 31s 41ms/step - accuracy: 0.9905 - loss: 0.0244 - val_accuracy: 0.9872 - val_loss: 0.0365
# Epoch 4/6
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 30s 41ms/step - accuracy: 0.9930 - loss: 0.0180 - val_accuracy: 0.9825 - val_loss: 0.0729
# Epoch 5/6
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 30s 41ms/step - accuracy: 0.9939 - loss: 0.0155 - val_accuracy: 0.9819 - val_loss: 0.0616
# Epoch 6/6
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 30s 40ms/step - accuracy: 0.9941 - loss: 0.0179 - val_accuracy: 0.9828 - val_loss: 0.0625
#
# --5/5 fold--
#
# Epoch 1/6
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 30s 41ms/step - accuracy: 0.9884 - loss: 0.0306 - val_accuracy: 0.9931 - val_loss: 0.0246
# Epoch 2/6
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 30s 41ms/step - accuracy: 0.9920 - loss: 0.0221 - val_accuracy: 0.9934 - val_loss: 0.0196
# Epoch 3/6
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 31s 41ms/step - accuracy: 0.9928 - loss: 0.0176 - val_accuracy: 0.9929 - val_loss: 0.0199
# Epoch 4/6
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 30s 41ms/step - accuracy: 0.9951 - loss: 0.0138 - val_accuracy: 0.9922 - val_loss: 0.0228
# Epoch 5/6
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 31s 41ms/step - accuracy: 0.9954 - loss: 0.0119 - val_accuracy: 0.9911 - val_loss: 0.0244
# Epoch 6/6
# 741/741 ━━━━━━━━━━━━━━━━━━━━ 30s 41ms/step - accuracy: 0.9911 - loss: 0.0243 - val_accuracy: 0.9794 - val_loss: 0.0544
#
# --<Functional name=functional_34, built=True>--
#
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# Precision: 0.96340
# Recall: 0.97674
# F1 Score: 0.97002
# Accuracy : 0.94466
# ROC AUC Score: 0.78415

# %%
models = [_1DCNN_model, _GRU_model, _BiLSTM_model]
soft_ensemble(models, test_set)
hard_ensemble(models, test_set)
# Out:
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# Precision: 0.96871
# Recall: 0.99347
# F1 Score: 0.98093
# Accuracy : 0.88919
# ROC AUC Score: 0.78545
#
# Precision: 0.97090
# Recall: 0.98374
# F1 Score: 0.97728
# Accuracy : 0.87933
# ROC AUC Score: 0.79779
#
# Precision: 0.97674
# Recall: 0.96340
# F1 Score: 0.97002
# Accuracy : 0.85789
# ROC AUC Score: 0.83065
#
# --soft_ensembled_model--
# Precision: 0.97230
# Recall: 0.98882
# F1 Score: 0.98049
# Accuracy : 0.88235
# ROC AUC Score: 0.80894
#
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# --hard_ensembled_model--
# Precision: 0.97214
# Recall: 0.98824
# F1 Score: 0.98012
# Accuracy : 0.88200
# ROC AUC Score: 0.80769

# %%
_1DCNN_model.save('1DCNN_model.h5')
_GRU_model.save('GRU_model.h5')
_BiLSTM_model.save('BiLSTM_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import os
from glob import glob
import warnings
import random
warnings.filterwarnings('ignore')

import import_ipynb
import abuse_detecting_preprocessing as pp
import abuse_detecting_databuild as b

import pandas as pd
import numpy as np

import fasttext

import tensorflow as tf
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, Dropout, BatchNormalization, GRU
from tensorflow.keras.layers import LeakyReLU, Input, Bidirectional, LSTM, GlobalMaxPooling1D, concatenate, ReLU
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import callbacks
from scikeras.wrappers import KerasClassifier

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, precision_recall_curve, roc_curve
from sklearn.model_selection import GridSearchCV

import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# importing Jupyter notebook from abuse_detecting_preprocessing.ipynb
# ['ㅇㅡㄴㄹㅡㄹㅈㅏㄹㅇㅣ-ㄱㅣㄴㄷㅏ-ㅎㅏ-', 'ㄴㅡㄴㄹㅗㄹㅇㅢ-ㅅㅣㄴㅇㅣ-ㄷㅏ-']
#
# ['t1ㅇㅡㄴlckㄹㅡㄹㅈㅏㄹㅇㅣ-ㄱㅣㄴㄷㅏ-ㅎㅏ-', 'fakerㄴㅡㄴㄹㅗㄹㅇㅢ-ㅅㅣㄴㅇㅣ-ㄷㅏ-']
#
# importing Jupyter notebook from abuse_detecting_databuild.ipynb
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
def seed_everything(seed=0):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
SEED = 30
seed_everything(SEED)

# %%
def print_score(label, pred):
    print('Precision: {:.5f}'.format(precision_score(label, pred)))
    print('Recall: {:.5f}'.format(recall_score(label, pred)))
    print('F1 Score: {:.5f}'.format(f1_score(label, pred)))
    print('Accuracy : {:.5f}'.format(np.mean(label == pred)))
    print('ROC AUC Score: {:.5f}\n'.format(roc_auc_score(label, pred)))

# %%
def _1DCNN(dropout_rate, input_shape):
    
    model = Sequential()
    model.add(Conv1D(filters=64, kernel_size = 6, input_shape = input_shape))
    model.add(LeakyReLU(alpha=0.2))
    # input_shape = (25, 100)
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(dropout_rate))
    
    model.add(Conv1D(filters=128, kernel_size = 3))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(dropout_rate))
    
    model.add(Conv1D(filters=256, kernel_size = 1))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization())
    model.add(GlobalAveragePooling1D())
    model.add(Dropout(dropout_rate))  
    
    model.add(Dense(128))
    model.add(ReLU())
    model.add(Dense(1, activation ='sigmoid'))
    
    model.compile(loss = 'binary_crossentropy',
                  optimizer = 'Adam',
                  metrics = ['accuracy'])
    
    return model

# %%
def combined_pooling_lstm_model(dropout_rate, input_shape):
    
    inputs = Input(shape = input_shape)
    
    # Bidirectional LSTM layer
    x = Bidirectional(LSTM(64, return_sequences = True))(inputs)
    x = Bidirectional(LSTM(64, return_sequences = True))(x)
    
    # Average pool과 Max pool 생성
    avg_pool = GlobalAveragePooling1D()(x)
    max_pool = GlobalMaxPooling1D()(x)
    
    # 두 pool을 합친다.
    combined_pool = concatenate([avg_pool, max_pool])
    combined_pool = BatchNormalization()(combined_pool)
    
    # Dropout
    combined_pool = Dropout(dropout_rate)(combined_pool)
    
    # Output
    outputs = Dense(128)(combined_pool)
    outputs = ReLU()(outputs)
    
    outputs = Dense(1, activation='sigmoid')(outputs)
    
    model = Model(inputs = inputs, outputs = outputs)
    model.compile(loss = "binary_crossentropy",
                  optimizer = 'Adam',
                  metrics = ['accuracy'])
        
    return model

# %%
def GRU_model(dropout_rate, input_shape):
    
    model = Sequential()

    model.add(GRU(128, return_sequences = True, input_shape = input_shape))
    model.add(LeakyReLU(alpha = 0.2))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    model.add(GRU(64, return_sequences = True))
    model.add(LeakyReLU(alpha = 0.2))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    model.add(GRU(32, return_sequences = False))
    model.add(LeakyReLU(alpha = 0.2))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    # output
    model.add(Dense(32))
    model.add(ReLU())
    model.add(Dense(1, activation = 'sigmoid'))
    
    # Model compile
    model.compile(loss = 'binary_crossentropy',
                  optimizer ='Adam',
                  metrics = ['accuracy'])
    
    return model

# %%
def build_train(routes, input_,):
    fasttext_model = fasttext.load_model('fasttext_model.bin')
    
    df = pd.DataFrame()
    for r in routes:
        d = pd.read_csv(r)
        df = pd.concat([df,d], ignore_index = True)

    N = 5
    # df = df[['문장','악플/욕설']]
    # df = df.rename(columns = {'문장' : 'message', '악플/욕설' : 'label'})
    x_train = b.making_x_train(df['message'], input_, fasttext_model, N)
    y_train = np.array(df['label'])
    
    y_train = y_train.astype(np.float32)
    y_train = y_train.reshape(-1,1)
    
    x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, stratify = y_train, random_state = SEED,
                                                       train_size = 0.8, test_size = 0.2)
    print('x_train :', x_train.shape, 'y_train :', y_train.shape)
    print('x_test :', x_test.shape, 'y_test :', y_test.shape)

    return x_train, y_train, x_test, y_test

# %%
def train(model, train_set, k, epochs):
    x_train, y_train = train_set
    # train
    kf = KFold(n_splits = k, shuffle=True)

    for idx, (train_index, val_index) in enumerate(kf.split(x_train)):
        print(f'\n--{idx + 1}/{k} fold--\n')
        
        x_train_fold, x_val_fold = x_train[train_index], x_train[val_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]
        
        model.fit(x_train_fold, y_train_fold, epochs = epochs,
                  validation_data = (x_val_fold, y_val_fold), callbacks = [early_stopping])
        
    print(f'\n--{model}--\n')
    y_pred = np.round(model.predict(x_test))
    print_score(y_pred, y_test)
    
    return model

# %%
def my_GridSearch(model, train_set, param_grid, cv, input_shape, verbose = 0, n_jobs = 5):
    train, y = train_set

    classifier = KerasClassifier(build_fn = model, input_shape = input_shape, dropout_rate = 0.0)
    # GridSearchCV 모델로 초기화
    grid_model = GridSearchCV(estimator = classifier,
                           param_grid = param_grid,
                           scoring = 'roc_auc',
                           cv = cv)
    
    # 모델 fitting
    grid_model.fit(train, y)
    
    # 최적의 하이퍼파라미터 및 점수 출력
    print("Best parameters found: ", grid_model.best_params_)
    print("Best ROC AUC score: ", grid_model.best_score_)
    
    # 결과값 저장
    results = pd.DataFrame(grid_model.cv_results_)
    results = results.sort_values(by='mean_test_score', ascending=False)
    
    return results

# %%
def ensemble(models, test_set):
    x_test, y_test = test_set
    pred = np.column_stack([m.predict(x_test) for m in models])
    ensembled_pred = np.round(np.mean(pred, axis = 1))

    for p in pred.transpose():
        print_score(y_test, np.round(p))
    print('--ensembeld_model--')
    print_score(y_test, ensembled_pred)

# %%
K = 5
_input = 40 # 단어 길이
input_shape = (_input, 100) # fasttext 모델이 100개의 벡터로 반환함.
dropout_rate = 0.0
early_stopping = EarlyStopping(monitor = 'val_loss', patience = 5) 

data_routes = glob('chatting_datas/labeled_datas/*.csv')
# data_routes = glob('/Users/kim-yongjun/Documents/chatting_data/smile_gate_abuse_data/*')
x_train, y_train, x_test, y_test = build_train(data_routes, _input)
train_set = (x_train, y_train)
test_set = (x_test, y_test)
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# x_train : (3352, 40, 100) y_train : (3352, 1)
# x_test : (839, 40, 100) y_test : (839, 1)

# %%
cv = 5 # grid_search의 cv

param_grid = {'epochs': [6, 8, 10],
              'dropout_rate': [0.2, 0.3, 0.4]
             }
# 총 90 + 120 + 150 = 360회 수행.

# %%
_1DCNN_grid = my_GridSearch(_1DCNN, train_set, param_grid, cv, input_shape)

# %%
_1DCNN_grid[['rank_test_score', 'params', 'mean_test_score']]
# Out:
#    rank_test_score                               params  mean_test_score
# 3                1   {'dropout_rate': 0.3, 'epochs': 6}         0.805820
# 6                2   {'dropout_rate': 0.4, 'epochs': 6}         0.801680
# 8                3  {'dropout_rate': 0.4, 'epochs': 10}         0.799178
# 7                4   {'dropout_rate': 0.4, 'epochs': 8}         0.797957
# 4                5   {'dropout_rate': 0.3, 'epochs': 8}         0.787698
# 0                6   {'dropout_rate': 0.2, 'epochs': 6}         0.785576
# 1                7   {'dropout_rate': 0.2, 'epochs': 8}         0.778409
# 2                8  {'dropout_rate': 0.2, 'epochs': 10}         0.751344
# 5                9  {'dropout_rate': 0.3, 'epochs': 10}         0.743542

# %%
GRU_grid = my_GridSearch(GRU_model, train_set, param_grid, cv, input_shape)

# %%
GRU_grid[['rank_test_score', 'params', 'mean_test_score']]
# Out:
#    rank_test_score                               params  mean_test_score
# 5                1  {'dropout_rate': 0.3, 'epochs': 10}         0.835426
# 4                2   {'dropout_rate': 0.3, 'epochs': 8}         0.810124
# 8                3  {'dropout_rate': 0.4, 'epochs': 10}         0.807032
# 7                4   {'dropout_rate': 0.4, 'epochs': 8}         0.801730
# 3                5   {'dropout_rate': 0.3, 'epochs': 6}         0.786926
# 0                6   {'dropout_rate': 0.2, 'epochs': 6}         0.767133
# 2                7  {'dropout_rate': 0.2, 'epochs': 10}         0.767080
# 1                8   {'dropout_rate': 0.2, 'epochs': 8}         0.766626
# 6                9   {'dropout_rate': 0.4, 'epochs': 6}         0.724909

# %%
lstm_grid = my_GridSearch(combined_pooling_lstm_model, train_set, param_grid, cv, input_shape)

# %%
# lstm_grid[['rank_test_score', 'params']]
lstm_grid[['rank_test_score', 'params', 'mean_test_score']].reset_index(drop = True)
# Out:
#    rank_test_score                               params  mean_test_score
# 0                1   {'dropout_rate': 0.4, 'epochs': 6}         0.826137
# 1                2  {'dropout_rate': 0.2, 'epochs': 10}         0.817821
# 2                3  {'dropout_rate': 0.3, 'epochs': 10}         0.817462
# 3                4   {'dropout_rate': 0.3, 'epochs': 6}         0.812698
# 4                5  {'dropout_rate': 0.4, 'epochs': 10}         0.807726
# 5                6   {'dropout_rate': 0.3, 'epochs': 8}         0.807505
# 6                7   {'dropout_rate': 0.2, 'epochs': 6}         0.802590
# 7                8   {'dropout_rate': 0.4, 'epochs': 8}         0.797467
# 8                9   {'dropout_rate': 0.2, 'epochs': 8}         0.793414

# %%
_1DCNN_best = _1DCNN_grid[lstm_grid['rank_test_score'] == 1]['params'].item()
GRU_best = GRU_grid[lstm_grid['rank_test_score'] == 1]['params'].item()
BiLSTM_best = lstm_grid[lstm_grid['rank_test_score'] == 1]['params'].item()

_1DCNN_model = _1DCNN(_1DCNN_best['dropout_rate'], input_shape)
_GRU_model =  GRU_model(GRU_best['dropout_rate'], input_shape)
_BiLSTM_model = combined_pooling_lstm_model(BiLSTM_best['dropout_rate'], input_shape)

# %%
_1DCNN_model = train(_1DCNN_model, train_set, K, _1DCNN_best['epochs'])
_GRU_model = train(_GRU_model, train_set, K, GRU_best['epochs'])
_BiLSTM_model = train(_BiLSTM_model, train_set, K, BiLSTM_best['epochs'])
# Out:
# --1/5 fold--
#
# Epoch 1/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7230 - loss: 0.5377 - val_accuracy: 0.8584 - val_loss: 0.3765
# Epoch 2/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8719 - loss: 0.3334 - val_accuracy: 0.8689 - val_loss: 0.4673
# Epoch 3/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8925 - loss: 0.2943 - val_accuracy: 0.8793 - val_loss: 0.5030
# Epoch 4/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9059 - loss: 0.2672 - val_accuracy: 0.8763 - val_loss: 0.5383
# Epoch 5/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9070 - loss: 0.2409 - val_accuracy: 0.8838 - val_loss: 0.4348
# Epoch 6/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9248 - loss: 0.2027 - val_accuracy: 0.8808 - val_loss: 0.5658
#
# --2/5 fold--
#
# Epoch 1/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9201 - loss: 0.2497 - val_accuracy: 0.9121 - val_loss: 0.2402
# Epoch 2/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9220 - loss: 0.2192 - val_accuracy: 0.9076 - val_loss: 0.2827
# Epoch 3/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9253 - loss: 0.1962 - val_accuracy: 0.9001 - val_loss: 0.3455
# Epoch 4/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9387 - loss: 0.1650 - val_accuracy: 0.9091 - val_loss: 0.3640
# Epoch 5/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9478 - loss: 0.1497 - val_accuracy: 0.8972 - val_loss: 0.4217
# Epoch 6/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9444 - loss: 0.1570 - val_accuracy: 0.9016 - val_loss: 0.3958
#
# --3/5 fold--
#
# Epoch 1/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9342 - loss: 0.1961 - val_accuracy: 0.9403 - val_loss: 0.1251
# Epoch 2/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9528 - loss: 0.1463 - val_accuracy: 0.9299 - val_loss: 0.1707
# Epoch 3/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9570 - loss: 0.1205 - val_accuracy: 0.9224 - val_loss: 0.2523
# Epoch 4/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9575 - loss: 0.1175 - val_accuracy: 0.9388 - val_loss: 0.1958
# Epoch 5/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9626 - loss: 0.1019 - val_accuracy: 0.9343 - val_loss: 0.1931
# Epoch 6/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9580 - loss: 0.1162 - val_accuracy: 0.9448 - val_loss: 0.1560
#
# --4/5 fold--
#
# Epoch 1/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9503 - loss: 0.1272 - val_accuracy: 0.9761 - val_loss: 0.0857
# Epoch 2/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9678 - loss: 0.1133 - val_accuracy: 0.9493 - val_loss: 0.1384
# Epoch 3/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9607 - loss: 0.1029 - val_accuracy: 0.9373 - val_loss: 0.1902
# Epoch 4/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9663 - loss: 0.0966 - val_accuracy: 0.9627 - val_loss: 0.1303
# Epoch 5/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9755 - loss: 0.0819 - val_accuracy: 0.9537 - val_loss: 0.1359
# Epoch 6/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9757 - loss: 0.0736 - val_accuracy: 0.9149 - val_loss: 0.3229
#
# --5/5 fold--
#
# Epoch 1/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9660 - loss: 0.1040 - val_accuracy: 0.9522 - val_loss: 0.0979
# Epoch 2/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9702 - loss: 0.0821 - val_accuracy: 0.9672 - val_loss: 0.0723
# Epoch 3/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9667 - loss: 0.0880 - val_accuracy: 0.9418 - val_loss: 0.1486
# Epoch 4/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9763 - loss: 0.0671 - val_accuracy: 0.9030 - val_loss: 0.4103
# Epoch 5/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9641 - loss: 0.1109 - val_accuracy: 0.9343 - val_loss: 0.2010
# Epoch 6/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9768 - loss: 0.0703 - val_accuracy: 0.9119 - val_loss: 0.3801
#
# --<Sequential name=sequential_92, built=True>--
#
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Precision: 1.00000
# Recall: 0.89409
# F1 Score: 0.94408
# Accuracy : 0.89750
# ROC AUC Score: 0.94704
#
#
# --1/5 fold--
#
# Epoch 1/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.6585 - loss: 0.6399 - val_accuracy: 0.8703 - val_loss: 0.5821
# Epoch 2/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.8406 - loss: 0.4210 - val_accuracy: 0.8703 - val_loss: 0.4621
# Epoch 3/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.8589 - loss: 0.3878 - val_accuracy: 0.8703 - val_loss: 0.3797
# Epoch 4/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.8718 - loss: 0.3812 - val_accuracy: 0.8733 - val_loss: 0.3921
# Epoch 5/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.8664 - loss: 0.3860 - val_accuracy: 0.8629 - val_loss: 0.3899
#
# --2/5 fold--
#
# Epoch 1/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.8828 - loss: 0.3414 - val_accuracy: 0.8763 - val_loss: 0.3430
# Epoch 2/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.8842 - loss: 0.3239 - val_accuracy: 0.8659 - val_loss: 0.3484
# Epoch 3/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.8886 - loss: 0.2955 - val_accuracy: 0.8897 - val_loss: 0.3305
# Epoch 4/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9081 - loss: 0.2558 - val_accuracy: 0.8897 - val_loss: 0.3264
# Epoch 5/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9126 - loss: 0.2383 - val_accuracy: 0.8882 - val_loss: 0.3207
#
# --3/5 fold--
#
# Epoch 1/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9250 - loss: 0.2184 - val_accuracy: 0.9045 - val_loss: 0.2903
# Epoch 2/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9282 - loss: 0.2072 - val_accuracy: 0.8985 - val_loss: 0.2809
# Epoch 3/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9342 - loss: 0.1779 - val_accuracy: 0.9164 - val_loss: 0.2774
# Epoch 4/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9452 - loss: 0.1642 - val_accuracy: 0.9075 - val_loss: 0.3494
# Epoch 5/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9539 - loss: 0.1393 - val_accuracy: 0.9015 - val_loss: 0.2963
#
# --4/5 fold--
#
# Epoch 1/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9450 - loss: 0.1921 - val_accuracy: 0.9597 - val_loss: 0.1149
# Epoch 2/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9482 - loss: 0.1650 - val_accuracy: 0.9493 - val_loss: 0.1398
# Epoch 3/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9595 - loss: 0.1330 - val_accuracy: 0.9179 - val_loss: 0.1702
# Epoch 4/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9630 - loss: 0.1172 - val_accuracy: 0.8955 - val_loss: 0.2454
# Epoch 5/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9640 - loss: 0.1165 - val_accuracy: 0.8821 - val_loss: 0.3306
#
# --5/5 fold--
#
# Epoch 1/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9382 - loss: 0.1742 - val_accuracy: 0.9776 - val_loss: 0.0676
# Epoch 2/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9578 - loss: 0.1181 - val_accuracy: 0.9627 - val_loss: 0.1086
# Epoch 3/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9632 - loss: 0.1172 - val_accuracy: 0.9701 - val_loss: 0.0933
# Epoch 4/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9718 - loss: 0.0859 - val_accuracy: 0.9537 - val_loss: 0.1300
# Epoch 5/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9628 - loss: 0.0929 - val_accuracy: 0.9418 - val_loss: 0.2369
# Epoch 6/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9742 - loss: 0.0765 - val_accuracy: 0.9537 - val_loss: 0.1877
#
# --<Sequential name=sequential_93, built=True>--
#
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# Precision: 0.98072
# Recall: 0.92468
# F1 Score: 0.95187
# Accuracy : 0.91418
# ROC AUC Score: 0.86089
#
#
# --1/5 fold--
#
# Epoch 1/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8058 - loss: 0.4633 - val_accuracy: 0.8599 - val_loss: 0.4635
# Epoch 2/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9054 - loss: 0.2643 - val_accuracy: 0.8644 - val_loss: 0.3844
# Epoch 3/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9168 - loss: 0.2343 - val_accuracy: 0.8793 - val_loss: 0.3301
# Epoch 4/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9345 - loss: 0.1797 - val_accuracy: 0.8912 - val_loss: 0.3048
# Epoch 5/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9457 - loss: 0.1411 - val_accuracy: 0.8942 - val_loss: 0.3148
#
# --2/5 fold--
#
# Epoch 1/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9340 - loss: 0.2096 - val_accuracy: 0.9344 - val_loss: 0.1824
# Epoch 2/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9489 - loss: 0.1371 - val_accuracy: 0.9359 - val_loss: 0.1607
# Epoch 3/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9620 - loss: 0.1036 - val_accuracy: 0.9180 - val_loss: 0.2506
# Epoch 4/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9702 - loss: 0.0761 - val_accuracy: 0.9285 - val_loss: 0.2286
# Epoch 5/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9797 - loss: 0.0559 - val_accuracy: 0.9165 - val_loss: 0.2682
#
# --3/5 fold--
#
# Epoch 1/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9655 - loss: 0.1184 - val_accuracy: 0.9761 - val_loss: 0.0788
# Epoch 2/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9646 - loss: 0.0969 - val_accuracy: 0.9493 - val_loss: 0.1386
# Epoch 3/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9681 - loss: 0.0756 - val_accuracy: 0.9343 - val_loss: 0.2152
# Epoch 4/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9875 - loss: 0.0397 - val_accuracy: 0.9552 - val_loss: 0.1670
# Epoch 5/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9866 - loss: 0.0352 - val_accuracy: 0.9612 - val_loss: 0.1265
#
# --4/5 fold--
#
# Epoch 1/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9751 - loss: 0.0730 - val_accuracy: 0.9836 - val_loss: 0.0386
# Epoch 2/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9815 - loss: 0.0496 - val_accuracy: 0.9836 - val_loss: 0.0422
# Epoch 3/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9848 - loss: 0.0474 - val_accuracy: 0.9761 - val_loss: 0.0538
# Epoch 4/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9886 - loss: 0.0346 - val_accuracy: 0.9836 - val_loss: 0.0502
# Epoch 5/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9922 - loss: 0.0271 - val_accuracy: 0.9821 - val_loss: 0.0522
# Epoch 6/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9966 - loss: 0.0130 - val_accuracy: 0.9836 - val_loss: 0.0483
#
# --5/5 fold--
#
# Epoch 1/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9878 - loss: 0.0498 - val_accuracy: 0.9910 - val_loss: 0.0190
# Epoch 2/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9812 - loss: 0.0565 - val_accuracy: 0.9866 - val_loss: 0.0305
# Epoch 3/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9866 - loss: 0.0440 - val_accuracy: 0.9851 - val_loss: 0.0430
# Epoch 4/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9872 - loss: 0.0265 - val_accuracy: 0.9955 - val_loss: 0.0189
# Epoch 5/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9935 - loss: 0.0190 - val_accuracy: 0.9910 - val_loss: 0.0198
# Epoch 6/6
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9960 - loss: 0.0120 - val_accuracy: 0.9970 - val_loss: 0.0137
#
# --<Functional name=functional_1644, built=True>--
#
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# Precision: 0.95179
# Recall: 0.93127
# F1 Score: 0.94142
# Accuracy : 0.89750
# ROC AUC Score: 0.78522

# %%
models = [_1DCNN_model, _GRU_model, _BiLSTM_model]
pr = ensemble(models, test_set)
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Precision: 0.89409
# Recall: 1.00000
# F1 Score: 0.94408
# Accuracy : 0.84180
# ROC AUC Score: 0.61947
#
# Precision: 0.92468
# Recall: 0.98072
# F1 Score: 0.95187
# Accuracy : 0.80523
# ROC AUC Score: 0.73372
#
# Precision: 0.93127
# Recall: 0.95179
# F1 Score: 0.94142
# Accuracy : 0.78084
# ROC AUC Score: 0.75023
#
# --ensembeld_model--
# Precision: 0.91487
# Recall: 0.99174
# F1 Score: 0.95175
# Accuracy : 0.82003
# ROC AUC Score: 0.69941

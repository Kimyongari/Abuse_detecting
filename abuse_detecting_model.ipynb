# %%
import os
from glob import glob
import warnings
import random
warnings.filterwarnings('ignore')

import import_ipynb
import abuse_detecting_preprocessing as pp
import abuse_detecting_databuild as b

import pandas as pd
import numpy as np

import fasttext

import tensorflow as tf
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, Dropout, BatchNormalization, GRU
from tensorflow.keras.layers import LeakyReLU, Input, Bidirectional, LSTM, GlobalMaxPooling1D, concatenate, ReLU
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import callbacks
from scikeras.wrappers import KerasClassifier

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, precision_recall_curve, roc_curve
from sklearn.model_selection import GridSearchCV

import matplotlib.pyplot as plt
import seaborn as sns

# %%
def seed_everything(seed=0):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
SEED = 30
seed_everything(SEED)

# %%
def print_score(label, pred):
    print('Precision: {:.5f}'.format(precision_score(label, pred)))
    print('Recall: {:.5f}'.format(recall_score(label, pred)))
    print('F1 Score: {:.5f}'.format(f1_score(label, pred)))
    print('Accuracy : {:.5f}'.format(np.mean(label == pred)))
    print('ROC AUC Score: {:.5f}\n'.format(roc_auc_score(label, pred)))

# %%
def _1DCNN(dropout_rate, input_shape):
    
    model = Sequential()
    model.add(Conv1D(filters=64, kernel_size = 6, input_shape = input_shape))
    model.add(LeakyReLU(alpha=0.2))
    # input_shape = (25, 100)
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(dropout_rate))
    
    model.add(Conv1D(filters=128, kernel_size = 3))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(dropout_rate))
    
    model.add(Conv1D(filters=256, kernel_size = 1))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization())
    model.add(GlobalAveragePooling1D())
    model.add(Dropout(dropout_rate))  
    
    model.add(Dense(128))
    model.add(ReLU())
    model.add(Dense(1, activation ='sigmoid'))
    
    model.compile(loss = 'binary_crossentropy',
                  optimizer = 'Adam',
                  metrics = ['accuracy'])
    
    return model

# %%
def combined_pooling_lstm_model(dropout_rate, input_shape):
    
    inputs = Input(shape = input_shape)
    
    # Bidirectional LSTM layer
    x = Bidirectional(LSTM(64, return_sequences = True))(inputs)
    x = Bidirectional(LSTM(64, return_sequences = True))(x)
    
    # Average pool과 Max pool 생성
    avg_pool = GlobalAveragePooling1D()(x)
    max_pool = GlobalMaxPooling1D()(x)
    
    # 두 pool을 합친다.
    combined_pool = concatenate([avg_pool, max_pool])
    combined_pool = BatchNormalization()(combined_pool)
    
    # Dropout
    combined_pool = Dropout(dropout_rate)(combined_pool)
    
    # Output
    outputs = Dense(128)(combined_pool)
    outputs = ReLU()(outputs)
    
    outputs = Dense(1, activation='sigmoid')(outputs)
    
    model = Model(inputs = inputs, outputs = outputs)
    model.compile(loss = "binary_crossentropy",
                  optimizer = 'Adam',
                  metrics = ['accuracy'])
        
    return model

# %%
def GRU_model(dropout_rate, input_shape):
    
    model = Sequential()

    model.add(GRU(128, return_sequences = True, input_shape = input_shape))
    model.add(LeakyReLU(alpha = 0.2))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    model.add(GRU(64, return_sequences = True))
    model.add(LeakyReLU(alpha = 0.2))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    model.add(GRU(32, return_sequences = False))
    model.add(LeakyReLU(alpha = 0.2))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    # output
    model.add(Dense(32))
    model.add(ReLU())
    model.add(Dense(1, activation = 'sigmoid'))
    
    # Model compile
    model.compile(loss = 'binary_crossentropy',
                  optimizer ='Adam',
                  metrics = ['accuracy'])
    
    return model

# %%
def build_train(routes, input_,):
    fasttext_model = fasttext.load_model('/Users/kim-yongjun/Documents/abuse_detecting/fasttext_model.bin')
    
    df = pd.DataFrame()
    for r in routes:
        d = pd.read_csv(r)
        df = pd.concat([df,d], ignore_index = True)

    N = 5
    # df = df[['문장','악플/욕설']]
    # df = df.rename(columns = {'문장' : 'message', '악플/욕설' : 'label'})
    x_train = b.making_x_train(df['message'], input_, fasttext_model, N)
    y_train = np.array(df['label'])
    
    y_train = y_train.astype(np.float32)
    y_train = y_train.reshape(-1,1)
    
    x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, stratify = y_train, random_state = SEED,
                                                       train_size = 0.8, test_size = 0.2)
    print('x_train :', x_train.shape, 'y_train :', y_train.shape)
    print('x_test :', x_test.shape, 'y_test :', y_test.shape)

    return x_train, y_train, x_test, y_test

# %%
def train(model, train_set, k, epochs):
    x_train, y_train = train_set
    # train
    kf = KFold(n_splits = k, shuffle=True)

    for idx, (train_index, val_index) in enumerate(kf.split(x_train)):
        print(f'\n--{idx + 1}/{k} fold--\n')
        
        x_train_fold, x_val_fold = x_train[train_index], x_train[val_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]
        
        model.fit(x_train_fold, y_train_fold, epochs = epochs,
                  validation_data = (x_val_fold, y_val_fold), callbacks = [early_stopping])
        
    print(f'\n--{model}--\n')
    y_pred = np.round(model.predict(x_test))
    print_score(y_pred, y_test)
    
    return model

# %%
def my_GridSearch(model, train_set, param_grid, cv, input_shape, verbose = 0, n_jobs = 5):
    train, y = train_set

    classifier = KerasClassifier(build_fn = model, input_shape = input_shape, dropout_rate = 0.0)
    # GridSearchCV 모델로 초기화
    grid_model = GridSearchCV(estimator = classifier,
                           param_grid = param_grid,
                           scoring = 'roc_auc',
                           cv = cv)
    
    # 모델 fitting
    grid_model.fit(train, y)
    
    # 최적의 하이퍼파라미터 및 점수 출력
    print("Best parameters found: ", grid_model.best_params_)
    print("Best ROC AUC score: ", grid_model.best_score_)
    
    # 결과값 저장
    results = pd.DataFrame(grid_model.cv_results_)
    results = results.sort_values(by='mean_test_score', ascending=False)
    
    return results

# %%
def soft_ensemble(models, test_set):
    x_test, y_test = test_set
    pred = np.column_stack([m.predict(x_test) for m in models])
    ensembled_pred = np.round(np.mean(pred, axis = 1))

    for p in pred.transpose():
        print_score(y_test, np.round(p))
    print('--soft_ensembeld_model--')
    print_score(y_test, ensembled_pred)

# %%
def hard_ensemble(models, test_set):
    x_test, y_test = test_set
    l = len(models)
    pred = np.column_stack([np.round(m.predict(x_test)) for m in models])
    ensembled_pred = np.array([1 if np.sum(p) >= 2 else 0 for p in pred])
    # for p in pred.transpose():
    #     print_score(y_test, np.round(p))
    print('--hard_ensembeld_model--')
    print_score(y_test, ensembled_pred)

# %%
K = 5
_input = 40 # 단어 길이
input_shape = (_input, 100) # fasttext 모델이 100개의 벡터로 반환함.
dropout_rate = 0.0
early_stopping = EarlyStopping(monitor = 'val_loss', patience = 5) 

data_routes = glob('chatting_datas/labeled_datas/*.csv')
# data_routes = glob('/Users/kim-yongjun/Documents/chatting_data/smile_gate_abuse_data/*')
x_train, y_train, x_test, y_test = build_train(data_routes, _input)
train_set = (x_train, y_train)
test_set = (x_test, y_test)
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# x_train : (12154, 40, 100) y_train : (12154, 1)
# x_test : (3039, 40, 100) y_test : (3039, 1)

# %%
cv = 5 # grid_search의 cv

param_grid = {'epochs': [6, 8, 10],
              'dropout_rate': [0.2, 0.3, 0.4]
             }
# 총 90 + 120 + 150 = 360회 수행.

# %%
_1DCNN_grid = my_GridSearch(_1DCNN, train_set, param_grid, cv, input_shape)

# %%
_1DCNN_grid[['rank_test_score', 'params', 'mean_test_score']]
# Out:
#    rank_test_score                               params  mean_test_score
# 7                1   {'dropout_rate': 0.4, 'epochs': 8}         0.833654
# 6                2   {'dropout_rate': 0.4, 'epochs': 6}         0.822915
# 0                3   {'dropout_rate': 0.2, 'epochs': 6}         0.804435
# 8                4  {'dropout_rate': 0.4, 'epochs': 10}         0.801163
# 3                5   {'dropout_rate': 0.3, 'epochs': 6}         0.797306
# 5                6  {'dropout_rate': 0.3, 'epochs': 10}         0.793532
# 2                7  {'dropout_rate': 0.2, 'epochs': 10}         0.791775
# 4                8   {'dropout_rate': 0.3, 'epochs': 8}         0.788748
# 1                9   {'dropout_rate': 0.2, 'epochs': 8}         0.782619

# %%
GRU_grid = my_GridSearch(GRU_model, train_set, param_grid, cv, input_shape)

# %%
GRU_grid[['rank_test_score', 'params', 'mean_test_score']]
# Out:
#    rank_test_score                               params  mean_test_score
# 8                1  {'dropout_rate': 0.4, 'epochs': 10}         0.848118
# 4                2   {'dropout_rate': 0.3, 'epochs': 8}         0.839179
# 5                3  {'dropout_rate': 0.3, 'epochs': 10}         0.836711
# 3                4   {'dropout_rate': 0.3, 'epochs': 6}         0.829297
# 0                5   {'dropout_rate': 0.2, 'epochs': 6}         0.823926
# 7                6   {'dropout_rate': 0.4, 'epochs': 8}         0.822377
# 1                7   {'dropout_rate': 0.2, 'epochs': 8}         0.815840
# 2                8  {'dropout_rate': 0.2, 'epochs': 10}         0.796843
# 6                9   {'dropout_rate': 0.4, 'epochs': 6}         0.783146

# %%
lstm_grid = my_GridSearch(combined_pooling_lstm_model, train_set, param_grid, cv, input_shape)

# %%
# lstm_grid[['rank_test_score', 'params']]
lstm_grid[['rank_test_score', 'params', 'mean_test_score']].reset_index(drop = True)
# Out:
#    rank_test_score                               params  mean_test_score
# 0                1   {'dropout_rate': 0.4, 'epochs': 6}         0.844376
# 1                2  {'dropout_rate': 0.3, 'epochs': 10}         0.836789
# 2                3   {'dropout_rate': 0.2, 'epochs': 8}         0.836439
# 3                4   {'dropout_rate': 0.3, 'epochs': 6}         0.829884
# 4                5   {'dropout_rate': 0.2, 'epochs': 6}         0.823307
# 5                6  {'dropout_rate': 0.2, 'epochs': 10}         0.820952
# 6                7   {'dropout_rate': 0.4, 'epochs': 8}         0.817756
# 7                8  {'dropout_rate': 0.4, 'epochs': 10}         0.808001
# 8                9   {'dropout_rate': 0.3, 'epochs': 8}         0.799347

# %%
# _1DCNN_best = _1DCNN_grid[_1DCNN_grid['rank_test_score'] == 1]['params'].item()
# GRU_best = GRU_grid[GRU_grid['rank_test_score'] == 1]['params'].item()
# BiLSTM_best = lstm_grid[lstm_grid['rank_test_score'] == 1]['params'].item()
_1DCNN_best = {'dropout_rate': 0.4, 'epochs': 8}
GRU_best = {'dropout_rate': 0.4, 'epochs': 10}
BiLSTM_best = {'dropout_rate': 0.4, 'epochs': 6}
_1DCNN_model = _1DCNN(_1DCNN_best['dropout_rate'], input_shape)
_GRU_model =  GRU_model(GRU_best['dropout_rate'], input_shape)
_BiLSTM_model = combined_pooling_lstm_model(BiLSTM_best['dropout_rate'], input_shape)

# %%
_1DCNN_model = train(_1DCNN_model, train_set, K, _1DCNN_best['epochs'])
_GRU_model = train(_GRU_model, train_set, K, GRU_best['epochs'])
_BiLSTM_model = train(_BiLSTM_model, train_set, K, BiLSTM_best['epochs'])
# Out:
# --1/5 fold--
#
# Epoch 1/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8976 - loss: 0.3016 - val_accuracy: 0.9404 - val_loss: 0.1780
# Epoch 2/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9385 - loss: 0.1784 - val_accuracy: 0.9436 - val_loss: 0.1642
# Epoch 3/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9453 - loss: 0.1547 - val_accuracy: 0.9486 - val_loss: 0.1547
# Epoch 4/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9502 - loss: 0.1446 - val_accuracy: 0.9523 - val_loss: 0.1583
# Epoch 5/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9553 - loss: 0.1257 - val_accuracy: 0.9519 - val_loss: 0.1603
# Epoch 6/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9584 - loss: 0.1166 - val_accuracy: 0.9519 - val_loss: 0.1704
# Epoch 7/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9645 - loss: 0.1015 - val_accuracy: 0.9478 - val_loss: 0.2246
# Epoch 8/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9626 - loss: 0.1022 - val_accuracy: 0.9502 - val_loss: 0.2055
#
# --2/5 fold--
#
# Epoch 1/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9598 - loss: 0.1277 - val_accuracy: 0.9490 - val_loss: 0.1287
# Epoch 2/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9601 - loss: 0.1121 - val_accuracy: 0.9531 - val_loss: 0.1204
# Epoch 3/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9654 - loss: 0.0988 - val_accuracy: 0.9478 - val_loss: 0.1748
# Epoch 4/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9649 - loss: 0.0934 - val_accuracy: 0.9613 - val_loss: 0.1294
# Epoch 5/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9717 - loss: 0.0828 - val_accuracy: 0.9556 - val_loss: 0.1523
# Epoch 6/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9731 - loss: 0.0722 - val_accuracy: 0.9510 - val_loss: 0.2017
# Epoch 7/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9725 - loss: 0.0719 - val_accuracy: 0.9469 - val_loss: 0.2754
#
# --3/5 fold--
#
# Epoch 1/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9657 - loss: 0.1032 - val_accuracy: 0.9630 - val_loss: 0.0948
# Epoch 2/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9709 - loss: 0.0828 - val_accuracy: 0.9691 - val_loss: 0.1007
# Epoch 3/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9707 - loss: 0.0775 - val_accuracy: 0.9548 - val_loss: 0.1693
# Epoch 4/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9756 - loss: 0.0717 - val_accuracy: 0.9638 - val_loss: 0.1377
# Epoch 5/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9759 - loss: 0.0634 - val_accuracy: 0.9585 - val_loss: 0.1493
# Epoch 6/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9798 - loss: 0.0544 - val_accuracy: 0.9667 - val_loss: 0.1219
#
# --4/5 fold--
#
# Epoch 1/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9735 - loss: 0.0772 - val_accuracy: 0.9786 - val_loss: 0.0503
# Epoch 2/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9807 - loss: 0.0616 - val_accuracy: 0.9835 - val_loss: 0.0482
# Epoch 3/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9789 - loss: 0.0594 - val_accuracy: 0.9766 - val_loss: 0.0652
# Epoch 4/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9826 - loss: 0.0485 - val_accuracy: 0.9778 - val_loss: 0.0749
# Epoch 5/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9860 - loss: 0.0466 - val_accuracy: 0.9691 - val_loss: 0.1147
# Epoch 6/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9860 - loss: 0.0389 - val_accuracy: 0.9770 - val_loss: 0.0665
# Epoch 7/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9825 - loss: 0.0473 - val_accuracy: 0.9733 - val_loss: 0.0944
#
# --5/5 fold--
#
# Epoch 1/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9749 - loss: 0.0660 - val_accuracy: 0.9893 - val_loss: 0.0331
# Epoch 2/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9802 - loss: 0.0576 - val_accuracy: 0.9868 - val_loss: 0.0325
# Epoch 3/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9814 - loss: 0.0493 - val_accuracy: 0.9827 - val_loss: 0.0462
# Epoch 4/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9853 - loss: 0.0423 - val_accuracy: 0.9724 - val_loss: 0.0913
# Epoch 5/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9856 - loss: 0.0415 - val_accuracy: 0.9774 - val_loss: 0.0692
# Epoch 6/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9866 - loss: 0.0400 - val_accuracy: 0.9815 - val_loss: 0.0566
# Epoch 7/8
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9866 - loss: 0.0391 - val_accuracy: 0.9761 - val_loss: 0.0757
#
# --<Sequential name=sequential_2, built=True>--
#
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Precision: 0.99207
# Recall: 0.95820
# F1 Score: 0.97484
# Accuracy : 0.95327
# ROC AUC Score: 0.91363
#
#
# --1/5 fold--
#
# Epoch 1/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 12s 36ms/step - accuracy: 0.8737 - loss: 0.3770 - val_accuracy: 0.9202 - val_loss: 0.2802
# Epoch 2/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - accuracy: 0.9038 - loss: 0.3008 - val_accuracy: 0.8976 - val_loss: 0.2391
# Epoch 3/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - accuracy: 0.9134 - loss: 0.2268 - val_accuracy: 0.9527 - val_loss: 0.1446
# Epoch 4/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - accuracy: 0.9351 - loss: 0.1852 - val_accuracy: 0.9593 - val_loss: 0.1429
# Epoch 5/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - accuracy: 0.9457 - loss: 0.1710 - val_accuracy: 0.9576 - val_loss: 0.1463
#
# --2/5 fold--
#
# Epoch 1/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - accuracy: 0.9535 - loss: 0.1522 - val_accuracy: 0.9527 - val_loss: 0.1534
# Epoch 2/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - accuracy: 0.9540 - loss: 0.1389 - val_accuracy: 0.9556 - val_loss: 0.1343
# Epoch 3/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - accuracy: 0.9564 - loss: 0.1290 - val_accuracy: 0.9572 - val_loss: 0.1359
# Epoch 4/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - accuracy: 0.9643 - loss: 0.1138 - val_accuracy: 0.9391 - val_loss: 0.1673
# Epoch 5/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - accuracy: 0.9702 - loss: 0.1005 - val_accuracy: 0.9473 - val_loss: 0.1671
#
# --3/5 fold--
#
# Epoch 1/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - accuracy: 0.9597 - loss: 0.1225 - val_accuracy: 0.9564 - val_loss: 0.1197
# Epoch 2/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - accuracy: 0.9652 - loss: 0.1098 - val_accuracy: 0.9613 - val_loss: 0.1397
# Epoch 3/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - accuracy: 0.9683 - loss: 0.1028 - val_accuracy: 0.9687 - val_loss: 0.1092
# Epoch 4/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - accuracy: 0.9710 - loss: 0.0922 - val_accuracy: 0.9642 - val_loss: 0.1360
# Epoch 5/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - accuracy: 0.9709 - loss: 0.0902 - val_accuracy: 0.9572 - val_loss: 0.1433
#
# --4/5 fold--
#
# Epoch 1/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - accuracy: 0.9727 - loss: 0.0899 - val_accuracy: 0.9745 - val_loss: 0.0733
# Epoch 2/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - accuracy: 0.9771 - loss: 0.0778 - val_accuracy: 0.9794 - val_loss: 0.0698
# Epoch 3/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - accuracy: 0.9777 - loss: 0.0748 - val_accuracy: 0.9733 - val_loss: 0.0828
# Epoch 4/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - accuracy: 0.9794 - loss: 0.0694 - val_accuracy: 0.9737 - val_loss: 0.0781
# Epoch 5/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - accuracy: 0.9851 - loss: 0.0515 - val_accuracy: 0.9667 - val_loss: 0.1156
#
# --5/5 fold--
#
# Epoch 1/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - accuracy: 0.9761 - loss: 0.0713 - val_accuracy: 0.9757 - val_loss: 0.0737
# Epoch 2/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - accuracy: 0.9797 - loss: 0.0620 - val_accuracy: 0.9811 - val_loss: 0.0617
# Epoch 3/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - accuracy: 0.9833 - loss: 0.0537 - val_accuracy: 0.9827 - val_loss: 0.0551
# Epoch 4/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - accuracy: 0.9869 - loss: 0.0437 - val_accuracy: 0.9856 - val_loss: 0.0497
# Epoch 5/10
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - accuracy: 0.9879 - loss: 0.0373 - val_accuracy: 0.9658 - val_loss: 0.1126
#
# --<Sequential name=sequential_3, built=True>--
#
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Precision: 0.94158
# Recall: 0.97827
# F1 Score: 0.95957
# Accuracy : 0.92761
# ROC AUC Score: 0.77022
#
#
# --1/5 fold--
#
# Epoch 1/6
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 12s 36ms/step - accuracy: 0.8884 - loss: 0.2845 - val_accuracy: 0.9445 - val_loss: 0.2403
# Epoch 2/6
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 12s 41ms/step - accuracy: 0.9437 - loss: 0.1705 - val_accuracy: 0.9358 - val_loss: 0.1901
# Epoch 3/6
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 12s 41ms/step - accuracy: 0.9535 - loss: 0.1391 - val_accuracy: 0.9074 - val_loss: 0.2338
# Epoch 4/6
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - accuracy: 0.9578 - loss: 0.1195 - val_accuracy: 0.9235 - val_loss: 0.2316
# Epoch 5/6
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.9675 - loss: 0.0997 - val_accuracy: 0.9441 - val_loss: 0.1895
#
# --2/5 fold--
#
# Epoch 1/6
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 12s 41ms/step - accuracy: 0.9557 - loss: 0.1279 - val_accuracy: 0.9679 - val_loss: 0.0882
# Epoch 2/6
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 12s 41ms/step - accuracy: 0.9660 - loss: 0.0954 - val_accuracy: 0.9609 - val_loss: 0.0996
# Epoch 3/6
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 12s 41ms/step - accuracy: 0.9701 - loss: 0.0829 - val_accuracy: 0.9642 - val_loss: 0.1170
# Epoch 4/6
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - accuracy: 0.9775 - loss: 0.0653 - val_accuracy: 0.9654 - val_loss: 0.1158
# Epoch 5/6
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.9831 - loss: 0.0482 - val_accuracy: 0.9646 - val_loss: 0.1669
#
# --3/5 fold--
#
# Epoch 1/6
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - accuracy: 0.9740 - loss: 0.0809 - val_accuracy: 0.9831 - val_loss: 0.0500
# Epoch 2/6
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 12s 41ms/step - accuracy: 0.9814 - loss: 0.0495 - val_accuracy: 0.9815 - val_loss: 0.0594
# Epoch 3/6
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - accuracy: 0.9853 - loss: 0.0375 - val_accuracy: 0.9827 - val_loss: 0.0439
# Epoch 4/6
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.9917 - loss: 0.0250 - val_accuracy: 0.9831 - val_loss: 0.0454
# Epoch 5/6
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.9906 - loss: 0.0235 - val_accuracy: 0.9831 - val_loss: 0.0508
#
# --4/5 fold--
#
# Epoch 1/6
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.9855 - loss: 0.0427 - val_accuracy: 0.9938 - val_loss: 0.0222
# Epoch 2/6
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9895 - loss: 0.0351 - val_accuracy: 0.9897 - val_loss: 0.0277
# Epoch 3/6
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.9932 - loss: 0.0184 - val_accuracy: 0.9872 - val_loss: 0.0340
# Epoch 4/6
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 12s 41ms/step - accuracy: 0.9956 - loss: 0.0134 - val_accuracy: 0.9770 - val_loss: 0.0736
# Epoch 5/6
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 12s 41ms/step - accuracy: 0.9955 - loss: 0.0152 - val_accuracy: 0.9724 - val_loss: 0.0736
# Epoch 6/6
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - accuracy: 0.9925 - loss: 0.0209 - val_accuracy: 0.9872 - val_loss: 0.0416
#
# --5/5 fold--
#
# Epoch 1/6
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 12s 41ms/step - accuracy: 0.9879 - loss: 0.0350 - val_accuracy: 0.9926 - val_loss: 0.0202
# Epoch 2/6
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.9909 - loss: 0.0218 - val_accuracy: 0.9967 - val_loss: 0.0090
# Epoch 3/6
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.9971 - loss: 0.0093 - val_accuracy: 0.9971 - val_loss: 0.0148
# Epoch 4/6
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.9979 - loss: 0.0076 - val_accuracy: 0.9967 - val_loss: 0.0129
# Epoch 5/6
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.9951 - loss: 0.0150 - val_accuracy: 0.9885 - val_loss: 0.0308
# Epoch 6/6
# 304/304 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.9952 - loss: 0.0143 - val_accuracy: 0.9881 - val_loss: 0.0401
#
# --<Functional name=functional_69, built=True>--
#
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step
# Precision: 0.97656
# Recall: 0.97165
# F1 Score: 0.97410
# Accuracy : 0.95262
# ROC AUC Score: 0.85686

# %%
models = [_1DCNN_model, _GRU_model, _BiLSTM_model]
soft_ensemble(models, test_set)
hard_ensemble(models, test_set)
# Out:
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# Precision: 0.95820
# Recall: 0.99207
# F1 Score: 0.97484
# Accuracy : 0.86687
# ROC AUC Score: 0.77047
#
# Precision: 0.97827
# Recall: 0.94158
# F1 Score: 0.95957
# Accuracy : 0.81203
# ROC AUC Score: 0.86177
#
# Precision: 0.97165
# Recall: 0.97656
# F1 Score: 0.97410
# Accuracy : 0.84407
# ROC AUC Score: 0.83978
#
# --soft_ensembeld_model--
# Precision: 0.97084
# Recall: 0.98449
# F1 Score: 0.97762
# Accuracy : 0.85085
# ROC AUC Score: 0.83811
#
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# --hard_ensembeld_model--
# Precision: 0.97014
# Recall: 0.98413
# F1 Score: 0.97709
# Accuracy : 0.85112
# ROC AUC Score: 0.83417

# %%
_1DCNN_model.save('1DCNN_model.h5')
_GRU_model.save('GRU_model.h5')
_BiLSTM_model.save('BiLSTM_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

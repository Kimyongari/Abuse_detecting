# %%
import os
from glob import glob
import warnings
import random
warnings.filterwarnings('ignore')

import import_ipynb
import abuse_detecting_preprocessing as pp
import abuse_detecting_databuild as b

import pandas as pd
import numpy as np

import fasttext

import tensorflow as tf
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, Dropout, BatchNormalization, GRU
from tensorflow.keras.layers import LeakyReLU, Input, Bidirectional, LSTM, GlobalMaxPooling1D, concatenate, ReLU
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import callbacks
from scikeras.wrappers import KerasClassifier

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, precision_recall_curve, roc_curve
from sklearn.model_selection import GridSearchCV

import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# importing Jupyter notebook from abuse_detecting_preprocessing.ipynb
# ['ㅇㅡㄴㄹㅡㄹㅈㅏㄹㅇㅣ-ㄱㅣㄴㄷㅏ-ㅎㅏ-', 'ㄴㅡㄴㄹㅗㄹㅇㅢ-ㅅㅣㄴㅇㅣ-ㄷㅏ-']
#
# ['t1ㅇㅡㄴlckㄹㅡㄹㅈㅏㄹㅇㅣ-ㄱㅣㄴㄷㅏ-ㅎㅏ-', 'fakerㄴㅡㄴㄹㅗㄹㅇㅢ-ㅅㅣㄴㅇㅣ-ㄷㅏ-']
#
# importing Jupyter notebook from abuse_detecting_databuild.ipynb
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
def seed_everything(seed=0):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
SEED = 30
seed_everything(SEED)

# %%
def print_score(label, pred):
    print('Precision: {:.5f}'.format(precision_score(label, pred)))
    print('Recall: {:.5f}'.format(recall_score(label, pred)))
    print('F1 Score: {:.5f}'.format(f1_score(label, pred)))
    print('Accuracy : {:.5f}'.format(np.mean(label == pred)))
    print('ROC AUC Score: {:.5f}\n'.format(roc_auc_score(label, pred)))

# %%
def _1DCNN(dropout_rate, input_shape):
    
    model = Sequential()
    model.add(Conv1D(filters=64, kernel_size = 6, input_shape = input_shape))
    model.add(LeakyReLU(alpha=0.2))
    # input_shape = (25, 100)
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(dropout_rate))
    
    model.add(Conv1D(filters=128, kernel_size = 3))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(dropout_rate))
    
    model.add(Conv1D(filters=256, kernel_size = 1))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization())
    model.add(GlobalAveragePooling1D())
    model.add(Dropout(dropout_rate))  
    
    model.add(Dense(128))
    model.add(ReLU())
    model.add(Dense(1, activation ='sigmoid'))
    
    model.compile(loss = 'binary_crossentropy',
                  optimizer = 'Adam',
                  metrics = ['accuracy'])
    
    return model

# %%
def combined_pooling_lstm_model(dropout_rate, input_shape):
    
    inputs = Input(shape = input_shape)
    
    # Bidirectional LSTM layer
    x = Bidirectional(LSTM(64, return_sequences = True))(inputs)
    x = Bidirectional(LSTM(64, return_sequences = True))(x)
    
    # Average pool과 Max pool 생성
    avg_pool = GlobalAveragePooling1D()(x)
    max_pool = GlobalMaxPooling1D()(x)
    
    # 두 pool을 합친다.
    combined_pool = concatenate([avg_pool, max_pool])
    combined_pool = BatchNormalization()(combined_pool)
    
    # Dropout
    combined_pool = Dropout(dropout_rate)(combined_pool)
    
    # Output
    outputs = Dense(128)(combined_pool)
    outputs = ReLU()(outputs)
    
    outputs = Dense(1, activation='sigmoid')(outputs)
    
    model = Model(inputs = inputs, outputs = outputs)
    model.compile(loss = "binary_crossentropy",
                  optimizer = 'Adam',
                  metrics = ['accuracy'])
        
    return model

# %%
def GRU_model(dropout_rate, input_shape):
    
    model = Sequential()

    model.add(GRU(128, return_sequences = True, input_shape = input_shape))
    model.add(LeakyReLU(alpha = 0.2))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    model.add(GRU(64, return_sequences = True))
    model.add(LeakyReLU(alpha = 0.2))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    model.add(GRU(32, return_sequences = False))
    model.add(LeakyReLU(alpha = 0.2))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    # output
    model.add(Dense(32))
    model.add(ReLU())
    model.add(Dense(1, activation = 'sigmoid'))
    
    # Model compile
    model.compile(loss = 'binary_crossentropy',
                  optimizer ='Adam',
                  metrics = ['accuracy'])
    
    return model

# %%
def build_train(routes, input_,):
    fasttext_model = fasttext.load_model('fasttext_model.bin')
    
    df = pd.DataFrame()
    for r in routes:
        d = pd.read_csv(r)
        df = pd.concat([df,d], ignore_index = True)

    N = 5
    # df = df[['문장','악플/욕설']]
    # df = df.rename(columns = {'문장' : 'message', '악플/욕설' : 'label'})
    x_train = b.making_x_train(df['message'], input_, fasttext_model, N)
    y_train = np.array(df['label'])
    
    y_train = y_train.astype(np.float32)
    y_train = y_train.reshape(-1,1)
    
    x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, stratify = y_train, random_state = SEED,
                                                       train_size = 0.8, test_size = 0.2)
    print('x_train :', x_train.shape, 'y_train :', y_train.shape)
    print('x_test :', x_test.shape, 'y_test :', y_test.shape)

    return x_train, y_train, x_test, y_test

# %%
def train(model, train_set, k, epochs):
    x_train, y_train = train_set
    # train
    kf = KFold(n_splits = k, shuffle=True)

    for idx, (train_index, val_index) in enumerate(kf.split(x_train)):
        print(f'\n--{idx + 1}/{k} fold--\n')
        
        x_train_fold, x_val_fold = x_train[train_index], x_train[val_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]
        
        model.fit(x_train_fold, y_train_fold, epochs = epochs,
                  validation_data = (x_val_fold, y_val_fold), callbacks = [early_stopping])
        
    print(f'\n--{model}--\n')
    y_pred = np.round(model.predict(x_test))
    print_score(y_pred, y_test)
    
    return model

# %%
def my_GridSearch(model, train_set, param_grid, cv, input_shape, verbose = 0, n_jobs = 5):
    train, y = train_set

    classifier = KerasClassifier(build_fn = model, input_shape = input_shape, dropout_rate = 0.0)
    # GridSearchCV 모델로 초기화
    grid_model = GridSearchCV(estimator = classifier,
                           param_grid = param_grid,
                           scoring = 'roc_auc',
                           cv = cv)
    
    # 모델 fitting
    grid_model.fit(train, y)
    
    # 최적의 하이퍼파라미터 및 점수 출력
    print("Best parameters found: ", grid_model.best_params_)
    print("Best ROC AUC score: ", grid_model.best_score_)
    
    # 결과값 저장
    results = pd.DataFrame(grid_model.cv_results_)
    results = results.sort_values(by='mean_test_score', ascending=False)
    
    return results

# %%
def ensemble(models, test_set):
    x_test, y_test = test_set
    pred = np.column_stack([m.predict(x_test) for m in models])
    ensembled_pred = np.round(np.mean(pred, axis = 1))

    for p in pred.transpose():
        print_score(y_test, np.round(p))
    print('--ensembeld_model--')
    print_score(y_test, ensembled_pred)

# %%
K = 5
_input = 40 # 단어 길이
input_shape = (_input, 100) # fasttext 모델이 100개의 벡터로 반환함.
dropout_rate = 0.0
early_stopping = EarlyStopping(monitor = 'val_loss', patience = 5) 

data_routes = glob('chatting_datas/labeled_datas/*.csv')
# data_routes = glob('/Users/kim-yongjun/Documents/chatting_data/smile_gate_abuse_data/*')
x_train, y_train, x_test, y_test = build_train(data_routes, _input)
train_set = (x_train, y_train)
test_set = (x_test, y_test)
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# x_train : (3753, 40, 100) y_train : (3753, 1)
# x_test : (939, 40, 100) y_test : (939, 1)

# %%
cv = 5 # grid_search의 cv

param_grid = {'epochs': [6, 8, 10],
              'dropout_rate': [0.2, 0.3, 0.4]
             }
# 총 90 + 120 + 150 = 360회 수행.

# %%
_1DCNN_grid = my_GridSearch(_1DCNN, train_set, param_grid, cv, input_shape)

# %%
_1DCNN_grid[['rank_test_score', 'params', 'mean_test_score']]
# Out:
#    rank_test_score                               params  mean_test_score
# 6                1   {'dropout_rate': 0.4, 'epochs': 6}         0.820888
# 7                2   {'dropout_rate': 0.4, 'epochs': 8}         0.817285
# 3                3   {'dropout_rate': 0.3, 'epochs': 6}         0.814733
# 0                4   {'dropout_rate': 0.2, 'epochs': 6}         0.809141
# 8                5  {'dropout_rate': 0.4, 'epochs': 10}         0.800551
# 1                6   {'dropout_rate': 0.2, 'epochs': 8}         0.795471
# 5                7  {'dropout_rate': 0.3, 'epochs': 10}         0.795255
# 4                8   {'dropout_rate': 0.3, 'epochs': 8}         0.793663
# 2                9  {'dropout_rate': 0.2, 'epochs': 10}         0.784021

# %%
GRU_grid = my_GridSearch(GRU_model, train_set, param_grid, cv, input_shape)

# %%
GRU_grid[['rank_test_score', 'params', 'mean_test_score']]
# Out:
#    rank_test_score                               params  mean_test_score
# 8                1  {'dropout_rate': 0.4, 'epochs': 10}         0.822952
# 5                2  {'dropout_rate': 0.3, 'epochs': 10}         0.821948
# 7                3   {'dropout_rate': 0.4, 'epochs': 8}         0.820529
# 4                4   {'dropout_rate': 0.3, 'epochs': 8}         0.815572
# 0                5   {'dropout_rate': 0.2, 'epochs': 6}         0.802320
# 1                6   {'dropout_rate': 0.2, 'epochs': 8}         0.794299
# 3                7   {'dropout_rate': 0.3, 'epochs': 6}         0.790207
# 2                8  {'dropout_rate': 0.2, 'epochs': 10}         0.755305
# 6                9   {'dropout_rate': 0.4, 'epochs': 6}         0.738923

# %%
lstm_grid = my_GridSearch(combined_pooling_lstm_model, train_set, param_grid, cv, input_shape)

# %%
# lstm_grid[['rank_test_score', 'params']]
lstm_grid[['rank_test_score', 'params', 'mean_test_score']].reset_index(drop = True)
# Out:
#    rank_test_score                               params  mean_test_score
# 0                1  {'dropout_rate': 0.2, 'epochs': 10}         0.836805
# 1                2   {'dropout_rate': 0.4, 'epochs': 6}         0.832136
# 2                3  {'dropout_rate': 0.4, 'epochs': 10}         0.826671
# 3                4   {'dropout_rate': 0.3, 'epochs': 6}         0.825997
# 4                5   {'dropout_rate': 0.4, 'epochs': 8}         0.823220
# 5                6   {'dropout_rate': 0.2, 'epochs': 6}         0.822627
# 6                7  {'dropout_rate': 0.3, 'epochs': 10}         0.811929
# 7                8   {'dropout_rate': 0.2, 'epochs': 8}         0.807455
# 8                9   {'dropout_rate': 0.3, 'epochs': 8}         0.799515

# %%
_1DCNN_best = _1DCNN_grid[_1DCNN_grid['rank_test_score'] == 1]['params'].item()
GRU_best = GRU_grid[GRU_grid['rank_test_score'] == 1]['params'].item()
BiLSTM_best = lstm_grid[lstm_grid['rank_test_score'] == 1]['params'].item()


_1DCNN_model = _1DCNN(_1DCNN_best['dropout_rate'], input_shape)
_GRU_model =  GRU_model(GRU_best['dropout_rate'], input_shape)
_BiLSTM_model = combined_pooling_lstm_model(BiLSTM_best['dropout_rate'], input_shape)

# %%
_1DCNN_model = train(_1DCNN_model, train_set, K, _1DCNN_best['epochs'])
_GRU_model = train(_GRU_model, train_set, K, GRU_best['epochs'])
_BiLSTM_model = train(_BiLSTM_model, train_set, K, BiLSTM_best['epochs'])
# Out:
# --1/5 fold--
#
# Epoch 1/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7364 - loss: 0.5399 - val_accuracy: 0.8855 - val_loss: 0.3079
# Epoch 2/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9000 - loss: 0.2865 - val_accuracy: 0.8935 - val_loss: 0.3373
# Epoch 3/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9072 - loss: 0.2565 - val_accuracy: 0.9001 - val_loss: 0.3099
# Epoch 4/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9119 - loss: 0.2304 - val_accuracy: 0.9015 - val_loss: 0.3244
# Epoch 5/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9203 - loss: 0.2128 - val_accuracy: 0.8975 - val_loss: 0.3850
# Epoch 6/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9239 - loss: 0.1944 - val_accuracy: 0.9148 - val_loss: 0.3238
#
# --2/5 fold--
#
# Epoch 1/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9164 - loss: 0.2297 - val_accuracy: 0.9334 - val_loss: 0.1796
# Epoch 2/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9133 - loss: 0.2083 - val_accuracy: 0.9334 - val_loss: 0.1781
# Epoch 3/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9295 - loss: 0.1821 - val_accuracy: 0.9361 - val_loss: 0.1947
# Epoch 4/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9339 - loss: 0.1777 - val_accuracy: 0.9294 - val_loss: 0.2168
# Epoch 5/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9472 - loss: 0.1525 - val_accuracy: 0.9228 - val_loss: 0.2299
# Epoch 6/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9484 - loss: 0.1362 - val_accuracy: 0.9161 - val_loss: 0.2410
#
# --3/5 fold--
#
# Epoch 1/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9379 - loss: 0.1742 - val_accuracy: 0.9387 - val_loss: 0.1450
# Epoch 2/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9500 - loss: 0.1320 - val_accuracy: 0.9068 - val_loss: 0.2318
# Epoch 3/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9525 - loss: 0.1173 - val_accuracy: 0.9387 - val_loss: 0.1470
# Epoch 4/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9636 - loss: 0.1067 - val_accuracy: 0.9387 - val_loss: 0.1688
# Epoch 5/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9654 - loss: 0.0921 - val_accuracy: 0.9348 - val_loss: 0.1969
# Epoch 6/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9748 - loss: 0.0718 - val_accuracy: 0.9161 - val_loss: 0.3053
#
# --4/5 fold--
#
# Epoch 1/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9493 - loss: 0.1575 - val_accuracy: 0.9653 - val_loss: 0.0991
# Epoch 2/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9565 - loss: 0.1134 - val_accuracy: 0.9573 - val_loss: 0.1477
# Epoch 3/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9593 - loss: 0.1023 - val_accuracy: 0.9467 - val_loss: 0.1833
# Epoch 4/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9722 - loss: 0.0773 - val_accuracy: 0.9587 - val_loss: 0.1622
# Epoch 5/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9692 - loss: 0.0840 - val_accuracy: 0.9427 - val_loss: 0.2508
# Epoch 6/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9741 - loss: 0.0689 - val_accuracy: 0.9493 - val_loss: 0.2127
#
# --5/5 fold--
#
# Epoch 1/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9596 - loss: 0.1257 - val_accuracy: 0.9867 - val_loss: 0.0546
# Epoch 2/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9668 - loss: 0.0761 - val_accuracy: 0.9840 - val_loss: 0.0551
# Epoch 3/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9744 - loss: 0.0646 - val_accuracy: 0.9853 - val_loss: 0.0536
# Epoch 4/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9779 - loss: 0.0632 - val_accuracy: 0.9693 - val_loss: 0.1077
# Epoch 5/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9821 - loss: 0.0520 - val_accuracy: 0.9680 - val_loss: 0.0986
# Epoch 6/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9834 - loss: 0.0462 - val_accuracy: 0.9387 - val_loss: 0.1961
#
# --<Sequential name=sequential_92, built=True>--
#
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Precision: 0.99018
# Recall: 0.91497
# F1 Score: 0.95109
# Accuracy : 0.91161
# ROC AUC Score: 0.88731
#
#
# --1/5 fold--
#
# Epoch 1/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.6403 - loss: 0.6618 - val_accuracy: 0.8695 - val_loss: 0.5772
# Epoch 2/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.8628 - loss: 0.3975 - val_accuracy: 0.8708 - val_loss: 0.4626
# Epoch 3/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.8598 - loss: 0.3778 - val_accuracy: 0.8668 - val_loss: 0.3701
# Epoch 4/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.8719 - loss: 0.3747 - val_accuracy: 0.8735 - val_loss: 0.3551
# Epoch 5/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8742 - loss: 0.3484 - val_accuracy: 0.8602 - val_loss: 0.3554
#
# --2/5 fold--
#
# Epoch 1/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.8735 - loss: 0.3627 - val_accuracy: 0.8762 - val_loss: 0.3306
# Epoch 2/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.8716 - loss: 0.3461 - val_accuracy: 0.8695 - val_loss: 0.3164
# Epoch 3/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.8835 - loss: 0.3055 - val_accuracy: 0.8788 - val_loss: 0.3100
# Epoch 4/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.8928 - loss: 0.2847 - val_accuracy: 0.8935 - val_loss: 0.3091
# Epoch 5/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9048 - loss: 0.2607 - val_accuracy: 0.8975 - val_loss: 0.2910
#
# --3/5 fold--
#
# Epoch 1/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9073 - loss: 0.2620 - val_accuracy: 0.9374 - val_loss: 0.1919
# Epoch 2/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9172 - loss: 0.2334 - val_accuracy: 0.9321 - val_loss: 0.2209
# Epoch 3/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9307 - loss: 0.1989 - val_accuracy: 0.9254 - val_loss: 0.2177
# Epoch 4/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9338 - loss: 0.1975 - val_accuracy: 0.9254 - val_loss: 0.2427
# Epoch 5/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9464 - loss: 0.1633 - val_accuracy: 0.9241 - val_loss: 0.2348
#
# --4/5 fold--
#
# Epoch 1/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9394 - loss: 0.1874 - val_accuracy: 0.9693 - val_loss: 0.1034
# Epoch 2/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9411 - loss: 0.1772 - val_accuracy: 0.9693 - val_loss: 0.1106
# Epoch 3/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9441 - loss: 0.1584 - val_accuracy: 0.9640 - val_loss: 0.1133
# Epoch 4/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9538 - loss: 0.1371 - val_accuracy: 0.9613 - val_loss: 0.1343
# Epoch 5/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9524 - loss: 0.1435 - val_accuracy: 0.9507 - val_loss: 0.1637
#
# --5/5 fold--
#
# Epoch 1/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9534 - loss: 0.1399 - val_accuracy: 0.9733 - val_loss: 0.0911
# Epoch 2/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9672 - loss: 0.1115 - val_accuracy: 0.9507 - val_loss: 0.1357
# Epoch 3/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9726 - loss: 0.0924 - val_accuracy: 0.9680 - val_loss: 0.1158
# Epoch 4/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9753 - loss: 0.0833 - val_accuracy: 0.9320 - val_loss: 0.1820
# Epoch 5/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.9709 - loss: 0.0945 - val_accuracy: 0.8240 - val_loss: 0.6458
#
# --<Sequential name=sequential_93, built=True>--
#
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# Precision: 0.80123
# Recall: 0.95468
# F1 Score: 0.87125
# Accuracy : 0.79446
# ROC AUC Score: 0.65969
#
#
# --1/5 fold--
#
# Epoch 1/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.8228 - loss: 0.4141 - val_accuracy: 0.9015 - val_loss: 0.3693
# Epoch 2/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9103 - loss: 0.2476 - val_accuracy: 0.9055 - val_loss: 0.2980
# Epoch 3/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9323 - loss: 0.1923 - val_accuracy: 0.9201 - val_loss: 0.2545
# Epoch 4/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9434 - loss: 0.1359 - val_accuracy: 0.9068 - val_loss: 0.2858
# Epoch 5/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9692 - loss: 0.0930 - val_accuracy: 0.9108 - val_loss: 0.3397
#
# --2/5 fold--
#
# Epoch 1/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9472 - loss: 0.1719 - val_accuracy: 0.9454 - val_loss: 0.1383
# Epoch 2/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9604 - loss: 0.1120 - val_accuracy: 0.9574 - val_loss: 0.1245
# Epoch 3/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9716 - loss: 0.0782 - val_accuracy: 0.9321 - val_loss: 0.1519
# Epoch 4/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9879 - loss: 0.0406 - val_accuracy: 0.9294 - val_loss: 0.2281
# Epoch 5/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9920 - loss: 0.0236 - val_accuracy: 0.9361 - val_loss: 0.2298
#
# --3/5 fold--
#
# Epoch 1/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9698 - loss: 0.0923 - val_accuracy: 0.9467 - val_loss: 0.1240
# Epoch 2/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9673 - loss: 0.0906 - val_accuracy: 0.9840 - val_loss: 0.0628
# Epoch 3/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9824 - loss: 0.0542 - val_accuracy: 0.9800 - val_loss: 0.0649
# Epoch 4/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9871 - loss: 0.0278 - val_accuracy: 0.9840 - val_loss: 0.0625
# Epoch 5/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9937 - loss: 0.0144 - val_accuracy: 0.9814 - val_loss: 0.0646
#
# --4/5 fold--
#
# Epoch 1/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9843 - loss: 0.0507 - val_accuracy: 0.9947 - val_loss: 0.0236
# Epoch 2/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9874 - loss: 0.0350 - val_accuracy: 0.9907 - val_loss: 0.0388
# Epoch 3/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9925 - loss: 0.0256 - val_accuracy: 0.9880 - val_loss: 0.0316
# Epoch 4/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9965 - loss: 0.0151 - val_accuracy: 0.9907 - val_loss: 0.0256
# Epoch 5/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9989 - loss: 0.0044 - val_accuracy: 0.9920 - val_loss: 0.0240
# Epoch 6/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9978 - loss: 0.0060 - val_accuracy: 0.9800 - val_loss: 0.0590
#
# --5/5 fold--
#
# Epoch 1/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9952 - loss: 0.0187 - val_accuracy: 0.9893 - val_loss: 0.0305
# Epoch 2/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9887 - loss: 0.0337 - val_accuracy: 0.9693 - val_loss: 0.0995
# Epoch 3/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9834 - loss: 0.0409 - val_accuracy: 0.9787 - val_loss: 0.0601
# Epoch 4/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9907 - loss: 0.0305 - val_accuracy: 0.9813 - val_loss: 0.0536
# Epoch 5/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9911 - loss: 0.0270 - val_accuracy: 0.9827 - val_loss: 0.0670
#
# --<Functional name=functional_1644, built=True>--
#
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# Precision: 0.94847
# Recall: 0.94499
# F1 Score: 0.94672
# Accuracy : 0.90735
# ROC AUC Score: 0.79894

# %%
models = [_1DCNN_model, _GRU_model, _BiLSTM_model]
pr = ensemble(models, test_set)
# Out:
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Precision: 0.91497
# Recall: 0.99018
# F1 Score: 0.95109
# Accuracy : 0.82327
# ROC AUC Score: 0.69267
#
# Precision: 0.95468
# Recall: 0.80123
# F1 Score: 0.87125
# Accuracy : 0.66810
# ROC AUC Score: 0.77561
#
# Precision: 0.94499
# Recall: 0.94847
# F1 Score: 0.94672
# Accuracy : 0.77312
# ROC AUC Score: 0.79278
#
# --ensembeld_model--
# Precision: 0.94210
# Recall: 0.95828
# F1 Score: 0.95012
# Accuracy : 0.78174
# ROC AUC Score: 0.78559

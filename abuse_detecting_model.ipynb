# %%
import os
from glob import glob
import warnings
import random
warnings.filterwarnings('ignore')

import import_ipynb
import abuse_detecting_preprocessing as pp
import abuse_detecting_databuild as b

import pandas as pd
import numpy as np

import fasttext

import tensorflow as tf
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, Dropout, BatchNormalization, GRU
from tensorflow.keras.layers import LeakyReLU, Input, Bidirectional, LSTM, GlobalMaxPooling1D, concatenate, ReLU
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import callbacks
from scikeras.wrappers import KerasClassifier

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, precision_recall_curve, roc_curve
from sklearn.model_selection import GridSearchCV

import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# importing Jupyter notebook from abuse_detecting_preprocessing.ipynb
# ['ㅇㅡㄴㄹㅡㄹㅈㅏㄹㅇㅣ-ㄱㅣㄴㄷㅏ-ㅎㅏ-', 'ㄴㅡㄴㄹㅗㄹㅇㅢ-ㅅㅣㄴㅇㅣ-ㄷㅏ-']
#
# ['t1ㅇㅡㄴlckㄹㅡㄹㅈㅏㄹㅇㅣ-ㄱㅣㄴㄷㅏ-ㅎㅏ-', 'fakerㄴㅡㄴㄹㅗㄹㅇㅢ-ㅅㅣㄴㅇㅣ-ㄷㅏ-']
#
# importing Jupyter notebook from abuse_detecting_databuild.ipynb
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
def seed_everything(seed=0):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
SEED = 30
seed_everything(SEED)

# %%
def print_score(label, pred):
    print('Precision: {:.5f}'.format(precision_score(label, pred)))
    print('Recall: {:.5f}'.format(recall_score(label, pred)))
    print('F1 Score: {:.5f}'.format(f1_score(label, pred)))
    print('Accuracy : {:.5f}'.format(np.mean(label == pred)))
    print('ROC AUC Score: {:.5f}\n'.format(roc_auc_score(label, pred)))

# %%
def _1DCNN(dropout_rate, input_shape):
    
    model = Sequential()
    model.add(Conv1D(filters=64, kernel_size = 6, input_shape = input_shape))
    model.add(LeakyReLU(alpha=0.2))
    # input_shape = (25, 100)
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(dropout_rate))
    
    model.add(Conv1D(filters=128, kernel_size = 3))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(dropout_rate))
    
    model.add(Conv1D(filters=256, kernel_size = 1))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization())
    model.add(GlobalAveragePooling1D())
    model.add(Dropout(dropout_rate))  
    
    model.add(Dense(128))
    model.add(ReLU())
    model.add(Dense(1, activation ='sigmoid'))
    
    model.compile(loss = 'binary_crossentropy',
                  optimizer = 'Adam',
                  metrics = ['accuracy'])
    
    return model

# %%
def combined_pooling_lstm_model(dropout_rate, input_shape):
    
    inputs = Input(shape = input_shape)
    
    # Bidirectional LSTM layer
    x = Bidirectional(LSTM(64, return_sequences = True))(inputs)
    x = Bidirectional(LSTM(64, return_sequences = True))(x)
    
    # Average pool과 Max pool 생성
    avg_pool = GlobalAveragePooling1D()(x)
    max_pool = GlobalMaxPooling1D()(x)
    
    # 두 pool을 합친다.
    combined_pool = concatenate([avg_pool, max_pool])
    combined_pool = BatchNormalization()(combined_pool)
    
    # Dropout
    combined_pool = Dropout(dropout_rate)(combined_pool)
    
    # Output
    outputs = Dense(128)(combined_pool)
    outputs = ReLU()(outputs)
    
    outputs = Dense(1, activation='sigmoid')(outputs)
    
    model = Model(inputs = inputs, outputs = outputs)
    model.compile(loss = "binary_crossentropy",
                  optimizer = 'Adam',
                  metrics = ['accuracy'])
        
    return model

# %%
def GRU_model(dropout_rate, input_shape):
    
    model = Sequential()

    model.add(GRU(128, return_sequences = True, input_shape = input_shape))
    model.add(LeakyReLU(alpha = 0.2))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    model.add(GRU(64, return_sequences = True))
    model.add(LeakyReLU(alpha = 0.2))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    model.add(GRU(32, return_sequences = False))
    model.add(LeakyReLU(alpha = 0.2))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    # output
    model.add(Dense(32))
    model.add(ReLU())
    model.add(Dense(1, activation = 'sigmoid'))
    
    # Model compile
    model.compile(loss = 'binary_crossentropy',
                  optimizer ='Adam',
                  metrics = ['accuracy'])
    
    return model

# %%
def build_train(routes, input_,):
    fasttext_model = fasttext.load_model('/Users/kim-yongjun/Documents/abuse_detecting/fasttext_model.bin')
    
    df = pd.DataFrame()
    for r in routes:
        d = pd.read_csv(r)
        df = pd.concat([df,d], ignore_index = True)

    N = 5
    # df = df[['문장','악플/욕설']]
    # df = df.rename(columns = {'문장' : 'message', '악플/욕설' : 'label'})
    x_train = b.making_x_train(df['message'], input_, fasttext_model, N)
    y_train = np.array(df['label'])
    
    y_train = y_train.astype(np.float32)
    y_train = y_train.reshape(-1,1)
    
    x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, stratify = y_train, random_state = SEED,
                                                       train_size = 0.8, test_size = 0.2)
    print('x_train :', x_train.shape, 'y_train :', y_train.shape)
    print('x_test :', x_test.shape, 'y_test :', y_test.shape)

    return x_train, y_train, x_test, y_test

# %%
def train(model, train_set, k, epochs):
    x_train, y_train = train_set
    # train
    kf = KFold(n_splits = k, shuffle=True)

    for idx, (train_index, val_index) in enumerate(kf.split(x_train)):
        print(f'\n--{idx + 1}/{k} fold--\n')
        
        x_train_fold, x_val_fold = x_train[train_index], x_train[val_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]
        
        model.fit(x_train_fold, y_train_fold, epochs = epochs,
                  validation_data = (x_val_fold, y_val_fold), callbacks = [early_stopping])
        
    print(f'\n--{model}--\n')
    y_pred = np.round(model.predict(x_test))
    print_score(y_pred, y_test)
    
    return model

# %%
def my_GridSearch(model, train_set, param_grid, cv, input_shape, verbose = 0, n_jobs = 5):
    train, y = train_set

    classifier = KerasClassifier(build_fn = model, input_shape = input_shape, dropout_rate = 0.0)
    # GridSearchCV 모델로 초기화
    grid_model = GridSearchCV(estimator = classifier,
                           param_grid = param_grid,
                           scoring = 'roc_auc',
                           cv = cv)
    
    # 모델 fitting
    grid_model.fit(train, y)
    
    # 최적의 하이퍼파라미터 및 점수 출력
    print("Best parameters found: ", grid_model.best_params_)
    print("Best ROC AUC score: ", grid_model.best_score_)
    
    # 결과값 저장
    results = pd.DataFrame(grid_model.cv_results_)
    results = results.sort_values(by='mean_test_score', ascending=False)
    
    return results

# %%
def ensemble(models, test_set):
    x_test, y_test = test_set
    pred = np.column_stack([m.predict(x_test) for m in models])
    ensembled_pred = np.round(np.mean(pred, axis = 1))

    for p in pred.transpose():
        print_score(y_test, np.round(p))
    print('--ensembeld_model--')
    print_score(y_test, ensembled_pred)

# %%
K = 5
_input = 40 # 단어 길이
input_shape = (_input, 100) # fasttext 모델이 100개의 벡터로 반환함.
dropout_rate = 0.0
early_stopping = EarlyStopping(monitor = 'val_loss', patience = 5) 

data_routes = glob('chatting_datas/labeled_datas/*.csv')
# data_routes = glob('/Users/kim-yongjun/Documents/chatting_data/smile_gate_abuse_data/*')
x_train, y_train, x_test, y_test = build_train(data_routes, _input)
train_set = (x_train, y_train)
test_set = (x_test, y_test)
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# x_train : (4154, 40, 100) y_train : (4154, 1)
# x_test : (1039, 40, 100) y_test : (1039, 1)

# %%
cv = 5 # grid_search의 cv

param_grid = {'epochs': [6, 8, 10],
              'dropout_rate': [0.2, 0.3, 0.4]
             }
# 총 90 + 120 + 150 = 360회 수행.

# %%
_1DCNN_grid = my_GridSearch(_1DCNN, train_set, param_grid, cv, input_shape)

# %%
_1DCNN_grid[['rank_test_score', 'params', 'mean_test_score']]
# Out:
#    rank_test_score                               params  mean_test_score
# 7                1   {'dropout_rate': 0.4, 'epochs': 8}         0.833654
# 6                2   {'dropout_rate': 0.4, 'epochs': 6}         0.822915
# 0                3   {'dropout_rate': 0.2, 'epochs': 6}         0.804435
# 8                4  {'dropout_rate': 0.4, 'epochs': 10}         0.801163
# 3                5   {'dropout_rate': 0.3, 'epochs': 6}         0.797306
# 5                6  {'dropout_rate': 0.3, 'epochs': 10}         0.793532
# 2                7  {'dropout_rate': 0.2, 'epochs': 10}         0.791775
# 4                8   {'dropout_rate': 0.3, 'epochs': 8}         0.788748
# 1                9   {'dropout_rate': 0.2, 'epochs': 8}         0.782619

# %%
GRU_grid = my_GridSearch(GRU_model, train_set, param_grid, cv, input_shape)

# %%
GRU_grid[['rank_test_score', 'params', 'mean_test_score']]
# Out:
#    rank_test_score                               params  mean_test_score
# 8                1  {'dropout_rate': 0.4, 'epochs': 10}         0.848118
# 4                2   {'dropout_rate': 0.3, 'epochs': 8}         0.839179
# 5                3  {'dropout_rate': 0.3, 'epochs': 10}         0.836711
# 3                4   {'dropout_rate': 0.3, 'epochs': 6}         0.829297
# 0                5   {'dropout_rate': 0.2, 'epochs': 6}         0.823926
# 7                6   {'dropout_rate': 0.4, 'epochs': 8}         0.822377
# 1                7   {'dropout_rate': 0.2, 'epochs': 8}         0.815840
# 2                8  {'dropout_rate': 0.2, 'epochs': 10}         0.796843
# 6                9   {'dropout_rate': 0.4, 'epochs': 6}         0.783146

# %%
lstm_grid = my_GridSearch(combined_pooling_lstm_model, train_set, param_grid, cv, input_shape)

# %%
# lstm_grid[['rank_test_score', 'params']]
lstm_grid[['rank_test_score', 'params', 'mean_test_score']].reset_index(drop = True)
# Out:
#    rank_test_score                               params  mean_test_score
# 0                1   {'dropout_rate': 0.4, 'epochs': 6}         0.844376
# 1                2  {'dropout_rate': 0.3, 'epochs': 10}         0.836789
# 2                3   {'dropout_rate': 0.2, 'epochs': 8}         0.836439
# 3                4   {'dropout_rate': 0.3, 'epochs': 6}         0.829884
# 4                5   {'dropout_rate': 0.2, 'epochs': 6}         0.823307
# 5                6  {'dropout_rate': 0.2, 'epochs': 10}         0.820952
# 6                7   {'dropout_rate': 0.4, 'epochs': 8}         0.817756
# 7                8  {'dropout_rate': 0.4, 'epochs': 10}         0.808001
# 8                9   {'dropout_rate': 0.3, 'epochs': 8}         0.799347

# %%
# _1DCNN_best = _1DCNN_grid[_1DCNN_grid['rank_test_score'] == 1]['params'].item()
# GRU_best = GRU_grid[GRU_grid['rank_test_score'] == 1]['params'].item()
# BiLSTM_best = lstm_grid[lstm_grid['rank_test_score'] == 1]['params'].item()
_1DCNN_best = {'dropout_rate': 0.4, 'epochs': 10}
GRU_best = {'dropout_rate': 0.4, 'epochs': 6}
BiLSTM_best = {'dropout_rate': 0.2, 'epochs': 10}
_1DCNN_model = _1DCNN(_1DCNN_best['dropout_rate'], input_shape)
_GRU_model =  GRU_model(GRU_best['dropout_rate'], input_shape)
_BiLSTM_model = combined_pooling_lstm_model(BiLSTM_best['dropout_rate'], input_shape)

# %%
_1DCNN_model = train(_1DCNN_model, train_set, K, _1DCNN_best['epochs'])
_GRU_model = train(_GRU_model, train_set, K, GRU_best['epochs'])
_BiLSTM_model = train(_BiLSTM_model, train_set, K, BiLSTM_best['epochs'])
# Out:
# --1/5 fold--
#
# Epoch 1/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7960 - loss: 0.4601 - val_accuracy: 0.8857 - val_loss: 0.3178
# Epoch 2/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8746 - loss: 0.3292 - val_accuracy: 0.8893 - val_loss: 0.3327
# Epoch 3/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8912 - loss: 0.3047 - val_accuracy: 0.8929 - val_loss: 0.3044
# Epoch 4/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8987 - loss: 0.2705 - val_accuracy: 0.8989 - val_loss: 0.3128
# Epoch 5/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9127 - loss: 0.2445 - val_accuracy: 0.8965 - val_loss: 0.3306
# Epoch 6/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9139 - loss: 0.2285 - val_accuracy: 0.9001 - val_loss: 0.3478
# Epoch 7/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9178 - loss: 0.2177 - val_accuracy: 0.9037 - val_loss: 0.3211
# Epoch 8/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9233 - loss: 0.1905 - val_accuracy: 0.8929 - val_loss: 0.3136
#
# --2/5 fold--
#
# Epoch 1/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9146 - loss: 0.2202 - val_accuracy: 0.9314 - val_loss: 0.2097
# Epoch 2/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9261 - loss: 0.1862 - val_accuracy: 0.9230 - val_loss: 0.2266
# Epoch 3/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9420 - loss: 0.1620 - val_accuracy: 0.9025 - val_loss: 0.2650
# Epoch 4/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9427 - loss: 0.1517 - val_accuracy: 0.8893 - val_loss: 0.3019
# Epoch 5/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9420 - loss: 0.1393 - val_accuracy: 0.9146 - val_loss: 0.2639
# Epoch 6/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9531 - loss: 0.1163 - val_accuracy: 0.8989 - val_loss: 0.3005
#
# --3/5 fold--
#
# Epoch 1/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9331 - loss: 0.1831 - val_accuracy: 0.9615 - val_loss: 0.1095
# Epoch 2/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9480 - loss: 0.1493 - val_accuracy: 0.9434 - val_loss: 0.1520
# Epoch 3/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9456 - loss: 0.1424 - val_accuracy: 0.9422 - val_loss: 0.1456
# Epoch 4/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9549 - loss: 0.1287 - val_accuracy: 0.9398 - val_loss: 0.1529
# Epoch 5/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9553 - loss: 0.1215 - val_accuracy: 0.9290 - val_loss: 0.2606
# Epoch 6/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9663 - loss: 0.0871 - val_accuracy: 0.9410 - val_loss: 0.1847
#
# --4/5 fold--
#
# Epoch 1/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9401 - loss: 0.1556 - val_accuracy: 0.9603 - val_loss: 0.1100
# Epoch 2/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9581 - loss: 0.1190 - val_accuracy: 0.9675 - val_loss: 0.0820
# Epoch 3/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9618 - loss: 0.1017 - val_accuracy: 0.9422 - val_loss: 0.1596
# Epoch 4/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9687 - loss: 0.0841 - val_accuracy: 0.9483 - val_loss: 0.1547
# Epoch 5/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9732 - loss: 0.0801 - val_accuracy: 0.9314 - val_loss: 0.2499
# Epoch 6/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9740 - loss: 0.0771 - val_accuracy: 0.9290 - val_loss: 0.2691
# Epoch 7/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9671 - loss: 0.0867 - val_accuracy: 0.9422 - val_loss: 0.1720
#
# --5/5 fold--
#
# Epoch 1/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9565 - loss: 0.1303 - val_accuracy: 0.9867 - val_loss: 0.0392
# Epoch 2/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9725 - loss: 0.0840 - val_accuracy: 0.9566 - val_loss: 0.1125
# Epoch 3/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9734 - loss: 0.0623 - val_accuracy: 0.9711 - val_loss: 0.0749
# Epoch 4/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9710 - loss: 0.0747 - val_accuracy: 0.9470 - val_loss: 0.1766
# Epoch 5/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9808 - loss: 0.0539 - val_accuracy: 0.9735 - val_loss: 0.0668
# Epoch 6/8
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9826 - loss: 0.0493 - val_accuracy: 0.9651 - val_loss: 0.0965
#
# --<Sequential name=sequential, built=True>--
#
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Precision: 0.96321
# Recall: 0.92111
# F1 Score: 0.94169
# Accuracy : 0.89702
# ROC AUC Score: 0.79719
#
#
# --1/5 fold--
#
# Epoch 1/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - accuracy: 0.8034 - loss: 0.5053 - val_accuracy: 0.8556 - val_loss: 0.5727
# Epoch 2/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.8570 - loss: 0.4049 - val_accuracy: 0.8568 - val_loss: 0.4301
# Epoch 3/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.8661 - loss: 0.3856 - val_accuracy: 0.8544 - val_loss: 0.3904
# Epoch 4/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.8672 - loss: 0.3795 - val_accuracy: 0.8520 - val_loss: 0.3855
# Epoch 5/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.8643 - loss: 0.3572 - val_accuracy: 0.8592 - val_loss: 0.3965
#
# --2/5 fold--
#
# Epoch 1/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.8735 - loss: 0.3280 - val_accuracy: 0.9073 - val_loss: 0.2604
# Epoch 2/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.8811 - loss: 0.3032 - val_accuracy: 0.8111 - val_loss: 0.3809
# Epoch 3/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.8834 - loss: 0.2973 - val_accuracy: 0.9182 - val_loss: 0.2342
# Epoch 4/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.8949 - loss: 0.2715 - val_accuracy: 0.8845 - val_loss: 0.2669
# Epoch 5/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.9041 - loss: 0.2617 - val_accuracy: 0.9218 - val_loss: 0.2342
#
# --3/5 fold--
#
# Epoch 1/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.9108 - loss: 0.2414 - val_accuracy: 0.9206 - val_loss: 0.1944
# Epoch 2/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.9123 - loss: 0.2334 - val_accuracy: 0.9146 - val_loss: 0.2096
# Epoch 3/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.9233 - loss: 0.2111 - val_accuracy: 0.8448 - val_loss: 0.3659
# Epoch 4/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.9216 - loss: 0.2086 - val_accuracy: 0.9338 - val_loss: 0.2060
# Epoch 5/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9286 - loss: 0.1838 - val_accuracy: 0.9158 - val_loss: 0.2230
#
# --4/5 fold--
#
# Epoch 1/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9360 - loss: 0.1824 - val_accuracy: 0.9338 - val_loss: 0.1831
# Epoch 2/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9540 - loss: 0.1460 - val_accuracy: 0.9314 - val_loss: 0.1804
# Epoch 3/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9588 - loss: 0.1369 - val_accuracy: 0.9374 - val_loss: 0.2017
# Epoch 4/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9579 - loss: 0.1172 - val_accuracy: 0.9254 - val_loss: 0.2353
# Epoch 5/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.9707 - loss: 0.0960 - val_accuracy: 0.9278 - val_loss: 0.2575
#
# --5/5 fold--
#
# Epoch 1/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.9525 - loss: 0.1518 - val_accuracy: 0.9651 - val_loss: 0.0924
# Epoch 2/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.9671 - loss: 0.1102 - val_accuracy: 0.9530 - val_loss: 0.1328
# Epoch 3/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.9672 - loss: 0.0944 - val_accuracy: 0.9506 - val_loss: 0.1621
# Epoch 4/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.9708 - loss: 0.0929 - val_accuracy: 0.9578 - val_loss: 0.1323
# Epoch 5/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9742 - loss: 0.0749 - val_accuracy: 0.9386 - val_loss: 0.1807
#
# --<Sequential name=sequential_1, built=True>--
#
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# Precision: 0.90524
# Recall: 0.92588
# F1 Score: 0.91545
# Accuracy : 0.85563
# ROC AUC Score: 0.70060
#
#
# --1/5 fold--
#
# Epoch 1/6
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.7974 - loss: 0.4596 - val_accuracy: 0.8748 - val_loss: 0.4443
# Epoch 2/6
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9017 - loss: 0.2685 - val_accuracy: 0.8809 - val_loss: 0.3613
# Epoch 3/6
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9227 - loss: 0.2136 - val_accuracy: 0.8941 - val_loss: 0.3310
# Epoch 4/6
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9339 - loss: 0.1845 - val_accuracy: 0.9049 - val_loss: 0.2586
# Epoch 5/6
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9360 - loss: 0.1674 - val_accuracy: 0.9097 - val_loss: 0.2797
#
# --2/5 fold--
#
# Epoch 1/6
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9322 - loss: 0.1863 - val_accuracy: 0.9254 - val_loss: 0.2030
# Epoch 2/6
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9480 - loss: 0.1454 - val_accuracy: 0.9434 - val_loss: 0.1695
# Epoch 3/6
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9582 - loss: 0.1051 - val_accuracy: 0.9290 - val_loss: 0.2104
# Epoch 4/6
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9688 - loss: 0.0806 - val_accuracy: 0.9194 - val_loss: 0.2543
# Epoch 5/6
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9738 - loss: 0.0675 - val_accuracy: 0.9206 - val_loss: 0.2414
#
# --3/5 fold--
#
# Epoch 1/6
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9537 - loss: 0.1366 - val_accuracy: 0.9699 - val_loss: 0.0777
# Epoch 2/6
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9683 - loss: 0.0794 - val_accuracy: 0.9759 - val_loss: 0.0633
# Epoch 3/6
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9829 - loss: 0.0517 - val_accuracy: 0.9783 - val_loss: 0.0544
# Epoch 4/6
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9830 - loss: 0.0481 - val_accuracy: 0.9471 - val_loss: 0.1529
# Epoch 5/6
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9876 - loss: 0.0358 - val_accuracy: 0.9759 - val_loss: 0.0754
#
# --4/5 fold--
#
# Epoch 1/6
#   1/104 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9375 - loss: 0.0832

# %%
models = [_1DCNN_model, _GRU_model, _BiLSTM_model]
pr = ensemble(models, test_set)
# Out:
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Precision: 0.91186
# Recall: 0.96878
# F1 Score: 0.93946
# Accuracy : 0.80318
# ROC AUC Score: 0.68862
#
# Precision: 0.91649
# Recall: 0.95429
# F1 Score: 0.93501
# Accuracy : 0.78989
# ROC AUC Score: 0.70250
#
# Precision: 0.92463
# Recall: 0.97101
# F1 Score: 0.94725
# Accuracy : 0.79549
# ROC AUC Score: 0.73551
#
# --ensembeld_model--
# Precision: 0.92138
# Recall: 0.97993
# F1 Score: 0.94976
# Accuracy : 0.80388
# ROC AUC Score: 0.72588
